# %% [markdown]
# <a href="https://colab.research.google.com/github/TAUforPython/BioMedAI/blob/main/ML%20TMS%20feature%20Shapley%20vectors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# --- Install necessary packages (if not already installed in the environment) ---
# We'll use H2O for AutoML
# !pip install h2o --quiet

# --- Import necessary libraries ---
import pandas as pd
import numpy as np
import h2o
from h2o.automl import H2OAutoML
import warnings
warnings.filterwarnings("ignore") # Suppress potential warnings

# --- 1. Initialize H2O ---
print("Initializing H2O...")
h2o.init()
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.0/266.0 MB 3.8 MB/s eta 0:00:00
# Initializing H2O...
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "17.0.16" 2025-07-15; OpenJDK Runtime Environment (build 17.0.16+8-Ubuntu-0ubuntu122.04.1); OpenJDK 64-Bit Server VM (build 17.0.16+8-Ubuntu-0ubuntu122.04.1, mixed mode, sharing)
#   Starting server from /usr/local/lib/python3.12/dist-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmpdxvih05g
#   JVM stdout: /tmp/tmpdxvih05g/h2o_unknownUser_started_from_python.out
#   JVM stderr: /tmp/tmpdxvih05g/h2o_unknownUser_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  -----------------------------------------------------------------------------------------
# H2O_cluster_uptime:         03 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.46.0.9
# H2O_cluster_version_age:    14 days, 12 hours and 48 minutes
# H2O_cluster_name:           H2O_from_python_unknownUser_vivqpd
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    3.168 Gb
# H2O_cluster_total_cores:    2
# H2O_cluster_allowed_cores:  2
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null, "colab_language_server": "/usr/colab/bin/language_service"}
# H2O_internal_security:      False
# Python_version:             3.12.12 final
# --------------------------  -----------------------------------------------------------------------------------------

# %%
link_url = 'https://raw.githubusercontent.com/TAUforPython/BioMedAI/refs/heads/main/test_datasets/tms_timeseries_clusters.csv'

raw_data = pd.read_csv(link_url, sep = ',')
raw_data = raw_data.drop('Unnamed: 0',axis=1)
raw_data.head(5)
# Out:
#     patient_id  Avg_Resp_Left_Mean  Avg_Resp_Left_Std  Avg_Resp_Left_Hurst  \
# 0  patient_ 1n           53.259528          12.009135             0.397920
# 1  patient_ 2n          123.597025          41.771269             1.163941
# 2  patient_ 3n           39.701583          21.652062             1.099086
# 3  patient_ 4n           73.540167          23.046395             0.802684
# 4  patient_ 5n          100.746296          14.629567             0.809085
#
#    Avg_Resp_Right_Mean  Avg_Resp_Right_Std  Avg_Resp_Right_Hurst  \
# 0           194.736574           40.132561              1.917325
# 1           109.284255           41.218117              1.462129
# 2            84.205208           32.102390              1.186651
# 3            64.819444           13.978575              1.351294
# 4            38.125000           10.383945              0.789748
#
#    Avg_Resp_DTW_Cluster  Inh_Thresh_DTW_Cluster
# 0                   0.0                       3
# 1                   1.0                       1
# 2                   3.0                       1
# 3                   1.0                       1
# 4                   1.0                       1

# %%
link_url = 'https://raw.githubusercontent.com/TAUforPython/BioMedAI/refs/heads/main/test_datasets/tms_raw_data.csv'

raw_data_pain = pd.read_csv(link_url, sep = ';')

# %%
table_with_pain = pd.merge(
    raw_data,
    raw_data_pain[['patient_id', 'pain_type']].dropna(),
    on = 'patient_id', how = 'left'
)

# %%
table_with_pain.fillna(2.0)
# Out:
#      patient_id  Avg_Resp_Left_Mean  Avg_Resp_Left_Std  Avg_Resp_Left_Hurst  \
# 0   patient_ 1n           53.259528          12.009135             0.397920
# 1   patient_ 2n          123.597025          41.771269             1.163941
# 2   patient_ 3n           39.701583          21.652062             1.099086
# 3   patient_ 4n           73.540167          23.046395             0.802684
# 4   patient_ 5n          100.746296          14.629567             0.809085
# ..          ...                 ...                ...                  ...
# 56  patient_ 43           76.422778          22.373236             0.975436
# 57  patient_ 44           83.317560          18.023992             1.785834
# 58  patient_ 45           86.609226          24.699766             0.965192
# 59  patient_ 46           98.417887          16.433997             0.459940
# 60  patient_ 47           64.550536          16.974346             1.955293
#
#     Avg_Resp_Right_Mean  Avg_Resp_Right_Std  Avg_Resp_Right_Hurst  \
# 0            194.736574           40.132561              1.917325
# 1            109.284255           41.218117              1.462129
# 2             84.205208           32.102390              1.186651
# 3             64.819444           13.978575              1.351294
# 4             38.125000           10.383945              0.789748
# ..                  ...                 ...                   ...
# 56            66.449074           14.436201              1.486417
# 57            76.647917           28.206003              1.772336
# 58            61.637611           23.023425              1.693853
# 59            89.208167           25.067659              1.602354
# 60           112.023495           20.394458              1.050213
#
#     Avg_Resp_DTW_Cluster  Inh_Thresh_DTW_Cluster  pain_type
# 0                    0.0                       3        2.0
# 1                    1.0                       1        2.0
# 2                    3.0                       1        2.0
# 3                    1.0                       1        2.0
# 4                    1.0                       1        2.0
# ..                   ...                     ...        ...
# 56                   1.0                       3        1.0
# 57                   1.0                       0        0.0
# 58                   1.0                       0        0.0
# 59                   3.0                       2        1.0
# 60                   3.0                       2        0.0
#
# [61 rows x 10 columns]

# %%
#df = raw_data
df = table_with_pain

# %%
# --- 3. Data Preprocessing for H2O ---
# Identify columns to use for modeling (features and potential targets)
# Exclude 'patient_id' as it's an identifier
all_columns = df.columns.tolist()
feature_columns = [col for col in all_columns if col != 'patient_id']

print(f"\nAll columns: {all_columns}")
print(f"\nFeature columns identified: {feature_columns}")

# Handle missing values (H2O can handle some NA, but for consistency in target evaluation,
# let's drop rows with any missing values in potential target columns)
# It's often better to let H2O handle missing values internally for features during modeling.
# However, for evaluating target performance, clean targets are needed.
# Let's drop rows where ANY column has missing values for this analysis.
df_clean = df.dropna()
print(f"\nShape after dropping rows with missing values: {df_clean.shape}")

X_clean_df = df_clean[feature_columns].copy()
y_potential_df = df_clean[feature_columns] # All features are potential targets

# Convert the clean pandas DataFrame to an H2O Frame
h2o_df = h2o.H2OFrame(df_clean)
print("\nData successfully converted to H2O Frame.")
# Out:
# All columns: ['patient_id', 'Avg_Resp_Left_Mean', 'Avg_Resp_Left_Std', 'Avg_Resp_Left_Hurst', 'Avg_Resp_Right_Mean', 'Avg_Resp_Right_Std', 'Avg_Resp_Right_Hurst', 'Avg_Resp_DTW_Cluster', 'Inh_Thresh_DTW_Cluster', 'pain_type']
#
# Feature columns identified: ['Avg_Resp_Left_Mean', 'Avg_Resp_Left_Std', 'Avg_Resp_Left_Hurst', 'Avg_Resp_Right_Mean', 'Avg_Resp_Right_Std', 'Avg_Resp_Right_Hurst', 'Avg_Resp_DTW_Cluster', 'Inh_Thresh_DTW_Cluster', 'pain_type']
#
# Shape after dropping rows with missing values: (31, 10)
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
#
# Data successfully converted to H2O Frame.

# %%
# --- 4. Define a function to evaluate H2O AutoML performance for each potential target column ---
def find_best_target_h2o_automl(h2o_frame, feature_cols, potential_target_cols, max_runtime_secs=120):
    """
    Iterates through each column in potential_target_cols, treating it as a target,
    and uses H2O AutoML to build a model. The performance (e.g., R2 for regression,
    AUC/M logloss for classification) of the model is used as a proxy to determine
    the 'best' target column. Higher performance might indicate that the column
    is easier to predict from the other features, suggesting a strong underlying
    relationship or structure.
    """
    results = {}
    best_score = float('-inf') # We'll use a generic 'score', taking the primary metric
    best_column = None
    best_task = None
    best_leaderboard = None

    for col in potential_target_cols:
        print(f"\n--- Evaluating '{col}' as potential target ---")
        y = col
        X = [c for c in feature_cols if c != y] # Use all other features as predictors

        # Determine task type based on the target column's data type in the H2O frame
        h2o_type = h2o_frame.type(col)
        print(f"  H2O determined type for '{col}': {h2o_type}")

        # H2O usually infers 'enum' for categorical/string and 'int'/'real' for numeric.
        # For integer columns that might represent clusters (classification),
        # H2O might still treat them as regression. We might need to explicitly convert.
        # Let's assume H2O's inference is mostly correct for now, but check unique values.
        unique_vals_frame = h2o_frame[y].unique()
        unique_count = unique_vals_frame.nrows
        total_count = h2o_frame.nrows
        print(f"  Unique values in '{col}': {unique_count}")

        if h2o_type == 'enum' or unique_count < max(2, total_count * 0.05): # Treat as classification
             task = 'classification'
             # Ensure the target is treated as enum if it's numeric but categorical
             h2o_frame[y] = h2o_frame[y].asfactor()
        elif h2o_type in ['int', 'real']:
             task = 'regression'
        else:
            print(f"  Skipping '{col}' due to unsupported H2O type: {h2o_type}")
            continue

        print(f"  Determined task type: {task}")

        # Split the H2O frame
        train, test = h2o_frame.split_frame(ratios=[0.8], seed=42)

        # Initialize H2O AutoML
        aml = H2OAutoML(
            max_runtime_secs=max_runtime_secs, # Run for max 2 minutes per target
            seed=42,
            verbosity='info' # Can be 'info', 'warn', 'quiet' to manage output
        )

        # Fit the AutoML model
        print(f"  Fitting H2O AutoML for {task} on '{col}'...")
        aml.train(x=X, y=y, training_frame=train)

        # Check the leaderboard for the best model's performance
        lb = aml.leaderboard
        print(lb.head())

        if lb.nrows == 0:
            print(f"  No models were trained successfully for target '{col}'. Skipping.")
            continue

        # Get the primary metric for the best model
        # H2O AutoML leaderboard has standard column names.
        # For regression: 'r2', 'rmse', 'mae', 'deviance'
        # For classification: 'mean_per_class_error', 'logloss', 'AUC' (if binary), 'AUCpr'
        # We'll take the best model's R2 for regression or mean_per_class_error (minimize) or logloss (minimize) for classification.
        best_model_id = lb[0, 'model_id']
        print(f"  Best model for '{col}': {best_model_id}")

        if task == 'regression':
            # Look for R2 score (higher is better)
            if 'r2' in lb.columns:
                score_val = lb[0, 'r2']
                score_name = "R2"
                if score_val is not None:
                    score_val = float(score_val) # H2O returns H2OFloat, convert to Python float
                    score = score_val # Higher R2 is better
                else:
                     print(f"    R2 not found for best model of '{col}', using 0.")
                     score = 0.0
            else:
                # If R2 is not present (e.g., if all models failed to report it), use another metric like negative RMSE
                rmse_val = lb[0, 'rmse']
                if rmse_val is not None:
                    rmse_val = float(rmse_val)
                    score = -rmse_val # Negative RMSE, so higher (less negative) is better
                    score_name = "-RMSE"
                else:
                     print(f"    R2 and RMSE not found for best model of '{col}', using 0.")
                     score = 0.0
                     score_name = "Placeholder"

        elif task == 'classification':
             # Look for mean_per_class_error (lower is better) or logloss (lower is better)
             # We want a score where HIGHER is better, so we'll use negative error or inverse of logloss if needed.
             # logloss is usually lower for better models. We can use negative logloss.
             if 'logloss' in lb.columns and lb[0, 'logloss'] is not None:
                 logloss_val = float(lb[0, 'logloss'])
                 score = -logloss_val # Negative logloss, so higher (less negative) is better
                 score_name = "-LogLoss"
             elif 'mean_per_class_error' in lb.columns and lb[0, 'mean_per_class_error'] is not None:
                  mce_val = float(lb[0, 'mean_per_class_error'])
                  score = -mce_val # Negative mean per class error, so higher (less negative) is better
                  score_name = "-MeanPerClassError"
             elif 'auc' in lb.columns and lb[0, 'auc'] is not None: # For binary classification
                  auc_val = float(lb[0, 'auc'])
                  score = auc_val # AUC, higher is better
                  score_name = "AUC"
             else:
                 print(f"    No standard classification metric found for best model of '{col}', using 0.")
                 score = 0.0
                 score_name = "Placeholder"

        print(f"  Best {score_name} for '{col}': {score:.4f}")

        results[col] = {
            'score': score,
            'score_name': score_name,
            'task': task,
            'leaderboard': lb
        }

        # Update best column if current score is better
        # Note: This comparison works if score is consistently higher for better performance
        if score > best_score:
            best_score = score
            best_column = col
            best_task = task
            best_leaderboard = lb

    print("\n--- Summary of H2O AutoML Performance for Potential Targets ---")
    # Sort results by score (descending) for better readability
    sorted_results = sorted(results.items(), key=lambda item: item[1]['score'], reverse=True)
    for col, res in sorted_results:
        print(f"  {col:<25} | {res['score_name']:<15} | {res['score']:.4f} | Task: {res['task']}")
    print(f"\nBest target column based on H2O AutoML performance: '{best_column}' with {results[best_column]['score_name']}: {best_score:.4f} (Task: {best_task})")

    return best_column, best_score, best_task, results, best_leaderboard


# --- Run the H2O AutoML-based target identification ---
best_target_col, best_score, best_task, all_results, best_lb = find_best_target_h2o_automl(
    h2o_df, feature_columns, y_potential_df.columns, max_runtime_secs=120
)

# --- Print the leaderboard for the best target ---
print(f"\n--- Leaderboard for the Best Target ('{best_target_col}') ---")
print(best_lb)

# --- 5. Shutdown H2O ---
print("\nShutting down H2O...")
h2o.shutdown(prompt=False)

print("\nDone.")
# Out:
# --- Evaluating 'Avg_Resp_Left_Mean' as potential target ---
#   H2O determined type for 'Avg_Resp_Left_Mean': real
#   Unique values in 'Avg_Resp_Left_Mean': 30
#   Determined task type: regression
#   Fitting H2O AutoML for regression on 'Avg_Resp_Left_Mean'...
# AutoML progress: |
# 05:29:29.54: Project: AutoML_1_20251209_52928
# 05:29:29.59: 5-fold cross-validation will be used.
# 05:29:29.59: Setting stopping tolerance adaptively based on the training frame: 0.05
# 05:29:29.60: Build control seed: 42
# 05:29:29.60: training frame: Frame key: AutoML_1_20251209_52928_training_py_3_sid_9690    cols: 10    rows: 27  chunks: 1    size: 2465  checksum: 926882371780204145
# 05:29:29.61: validation frame: NULL
# 05:29:29.61: leaderboard frame: NULL
# 05:29:29.63: blending frame: NULL
# 05:29:29.64: response column: Avg_Resp_Left_Mean
# 05:29:29.64: fold column: null
# 05:29:29.64: weights column: null
# 05:29:29.104: Loading execution steps: [{XGBoost : [def_2 (1g, 10w), def_1 (2g, 10w), def_3 (3g, 10w), grid_1 (4g, 90w), lr_search (6g, 30w)]}, {GLM : [def_1 (1g, 10w)]}, {DRF : [def_1 (2g, 10w), XRT (3g, 10w)]}, {GBM : [def_5 (1g, 10w), def_2 (2g, 10w), def_3 (2g, 10w), def_4 (2g, 10w), def_1 (3g, 10w), grid_1 (4g, 60w), lr_annealing (6g, 10w)]}, {DeepLearning : [def_1 (3g, 10w), grid_1 (4g, 30w), grid_2 (5g, 30w), grid_3 (5g, 30w)]}, {completion : [resume_best_grids (10g, 60w)]}, {StackedEnsemble : [best_of_family_1 (1g, 5w), best_of_family_2 (2g, 5w), best_of_family_3 (3g, 5w), best_of_family_4 (4g, 5w), best_of_family_5 (5g, 5w), all_2 (2g, 10w), all_3 (3g, 10w), all_4 (4g, 10w), all_5 (5g, 10w), monotonic (6g, 10w), best_of_family_gbm (6g, 10w), all_gbm (7g, 10w), best_of_family_xglm (8g, 10w), all_xglm (8g, 10w), best_of_family (10g, 10w), best_N (10g, 10w)]}]
# 05:29:29.150: AutoML job created: 2025.12.09 05:29:28.976
# 05:29:29.151: AutoML build started: 2025.12.09 05:29:29.150
# 05:29:29.197: AutoML: starting XGBoost_1_AutoML_1_20251209_52928 model training
#
# █
# 05:29:32.577: New leader: XGBoost_1_AutoML_1_20251209_52928, rmse: 47.01897648957601
# 05:29:32.584: AutoML: starting GLM_1_AutoML_1_20251209_52928 model training
#
# █
# 05:29:33.369: New leader: GLM_1_AutoML_1_20251209_52928, rmse: 30.136427290930435
# 05:29:33.377: AutoML: starting GBM_1_AutoML_1_20251209_52928 model training
# 05:29:33.377: _min_rows param, The dataset size is too small to split for min_rows=100.0: must have at least 200.0 (weighted) rows, but have only 27.0.
# 05:29:33.391: AutoML: starting StackedEnsemble_BestOfFamily_1_AutoML_1_20251209_52928 model training
# 05:29:33.653: AutoML: starting XGBoost_2_AutoML_1_20251209_52928 model training
#
# ███
# 05:29:38.689: AutoML: starting DRF_1_AutoML_1_20251209_52928 model training
#
# █
# 05:29:40.253: AutoML: starting GBM_2_AutoML_1_20251209_52928 model training
#
#
# 05:29:41.92: AutoML: starting GBM_3_AutoML_1_20251209_52928 model training
# 05:29:41.704: AutoML: starting GBM_4_AutoML_1_20251209_52928 model training
# 05:29:42.203: AutoML: starting StackedEnsemble_BestOfFamily_2_AutoML_1_20251209_52928 model training
# 05:29:42.349: AutoML: starting StackedEnsemble_AllModels_1_AutoML_1_20251209_52928 model training
#
# █
# 05:29:42.613: AutoML: starting XGBoost_3_AutoML_1_20251209_52928 model training
#
# █
# 05:29:44.819: AutoML: starting XRT_1_AutoML_1_20251209_52928 model training
#
# ██
# 05:29:46.117: AutoML: starting GBM_5_AutoML_1_20251209_52928 model training
# 05:29:46.919: AutoML: starting DeepLearning_1_AutoML_1_20251209_52928 model training
#
# █
# 05:29:47.435: AutoML: starting StackedEnsemble_BestOfFamily_3_AutoML_1_20251209_52928 model training
# 05:29:47.581: AutoML: starting StackedEnsemble_AllModels_2_AutoML_1_20251209_52928 model training
# 05:29:47.844: AutoML: starting XGBoost_grid_1_AutoML_1_20251209_52928 hyperparameter search
#
# ████████████
# 05:30:13.7: New leader: XGBoost_grid_1_AutoML_1_20251209_52928_model_8, rmse: 28.326813730400072
#
# ███████████
# 05:30:34.940: AutoML: starting GBM_grid_1_AutoML_1_20251209_52928 hyperparameter search
#
# ████████████████
# 05:31:05.962: AutoML: starting DeepLearning_grid_1_AutoML_1_20251209_52928 hyperparameter search
#
# █████████
# 05:31:21.475: AutoML: starting StackedEnsemble_BestOfFamily_4_AutoML_1_20251209_52928 model training
# 05:31:21.616: AutoML: starting StackedEnsemble_AllModels_3_AutoML_1_20251209_52928 model training
# 05:31:22.44: AutoML: starting DeepLearning_grid_2_AutoML_1_20251209_52928 hyperparameter search
#
# █
# 05:31:25.161: AutoML: starting DeepLearning_grid_3_AutoML_1_20251209_52928 hyperparameter search
#
# ██
# 05:31:28.204: AutoML: starting StackedEnsemble_AllModels_4_AutoML_1_20251209_52928 model training
# 05:31:28.520: Applying learning rate search on best XGBoost: XGBoost_grid_1_AutoML_1_20251209_52928_model_8
# 05:31:28.521: AutoML: starting XGBoost_lr_search_selection_AutoML_1_20251209_52928_select model training
#
# █| (done) 100%
#
# 05:31:29.614: Actual modeling steps: [{XGBoost : [def_2 (1g, 10w)]}, {GLM : [def_1 (1g, 10w)]}, {StackedEnsemble : [best_of_family_1 (1g, 5w)]}, {XGBoost : [def_1 (2g, 10w)]}, {DRF : [def_1 (2g, 10w)]}, {GBM : [def_2 (2g, 10w), def_3 (2g, 10w), def_4 (2g, 10w)]}, {StackedEnsemble : [best_of_family_2 (2g, 5w), all_2 (2g, 10w)]}, {XGBoost : [def_3 (3g, 10w)]}, {DRF : [XRT (3g, 10w)]}, {GBM : [def_1 (3g, 10w)]}, {DeepLearning : [def_1 (3g, 10w)]}, {StackedEnsemble : [best_of_family_3 (3g, 5w), all_3 (3g, 10w)]}, {XGBoost : [grid_1 (4g, 90w)]}, {GBM : [grid_1 (4g, 60w)]}, {DeepLearning : [grid_1 (4g, 30w)]}, {StackedEnsemble : [best_of_family_4 (4g, 5w), all_4 (4g, 10w)]}, {DeepLearning : [grid_2 (5g, 30w), grid_3 (5g, 30w)]}, {StackedEnsemble : [all_5 (5g, 10w)]}, {XGBoost : [lr_search (6g, 30w)]}]
# 05:31:29.614: AutoML build stopped: 2025.12.09 05:31:29.614
# 05:31:29.614: AutoML build done: built 120 models
# 05:31:29.614: AutoML duration:  2 min  0.464 sec
#
# model_id                                                rmse      mse      mae     rmsle    mean_residual_deviance
# XGBoost_grid_1_AutoML_1_20251209_52928_model_8       28.3268  802.408  20.8016  0.309949                   802.408
# DeepLearning_grid_1_AutoML_1_20251209_52928_model_3  29.3086  858.995  20.8057  0.322329                   858.995
# XGBoost_grid_1_AutoML_1_20251209_52928_model_10      29.407   864.769  21.1321  0.311353                   864.769
# XGBoost_grid_1_AutoML_1_20251209_52928_model_13      29.888   893.29   24.2981  0.313981                   893.29
# GLM_1_AutoML_1_20251209_52928                        30.1364  908.204  22.2556  0.322085                   908.204
# GBM_grid_1_AutoML_1_20251209_52928_model_24          30.1862  911.208  21.601   0.315827                   911.208
# GBM_grid_1_AutoML_1_20251209_52928_model_137         30.1862  911.208  21.601   0.315827                   911.208
# GBM_grid_1_AutoML_1_20251209_52928_model_8           30.1862  911.208  21.601   0.315827                   911.208
# GBM_grid_1_AutoML_1_20251209_52928_model_25          30.1892  911.39   21.5903  0.318422                   911.39
# GBM_grid_1_AutoML_1_20251209_52928_model_139         30.5169  931.278  21.521   0.319815                   931.278
# [10 rows x 6 columns]
#
#   Best model for 'Avg_Resp_Left_Mean': XGBoost_grid_1_AutoML_1_20251209_52928_model_8
#   Best -RMSE for 'Avg_Resp_Left_Mean': -28.3268
#
# --- Evaluating 'Avg_Resp_Left_Std' as potential target ---
#   H2O determined type for 'Avg_Resp_Left_Std': real
#   Unique values in 'Avg_Resp_Left_Std': 30
#   Determined task type: regression
#   Fitting H2O AutoML for regression on 'Avg_Resp_Left_Std'...
# AutoML progress: |
# 05:31:31.602: Project: AutoML_2_20251209_53131
# 05:31:31.602: 5-fold cross-validation will be used.
# 05:31:31.602: Setting stopping tolerance adaptively based on the training frame: 0.05
# 05:31:31.602: Build control seed: 42
# 05:31:31.602: training frame: Frame key: AutoML_2_20251209_53131_training_py_13_sid_9690    cols: 10    rows: 27  chunks: 1    size: 2465  checksum: 926882371780204145
# 05:31:31.602: validation frame: NULL
# 05:31:31.602: leaderboard frame: NULL
# 05:31:31.602: blending frame: NULL
# 05:31:31.602: response column: Avg_Resp_Left_Std
# 05:31:31.602: fold column: null
# 05:31:31.602: weights column: null
# 05:31:31.603: Loading execution steps: [{XGBoost : [def_2 (1g, 10w), def_1 (2g, 10w), def_3 (3g, 10w), grid_1 (4g, 90w), lr_search (6g, 30w)]}, {GLM : [def_1 (1g, 10w)]}, {DRF : [def_1 (2g, 10w), XRT (3g, 10w)]}, {GBM : [def_5 (1g, 10w), def_2 (2g, 10w), def_3 (2g, 10w), def_4 (2g, 10w), def_1 (3g, 10w), grid_1 (4g, 60w), lr_annealing (6g, 10w)]}, {DeepLearning : [def_1 (3g, 10w), grid_1 (4g, 30w), grid_2 (5g, 30w), grid_3 (5g, 30w)]}, {completion : [resume_best_grids (10g, 60w)]}, {StackedEnsemble : [best_of_family_1 (1g, 5w), best_of_family_2 (2g, 5w), best_of_family_3 (3g, 5w), best_of_family_4 (4g, 5w), best_of_family_5 (5g, 5w), all_2 (2g, 10w), all_3 (3g, 10w), all_4 (4g, 10w), all_5 (5g, 10w), monotonic (6g, 10w), best_of_family_gbm (6g, 10w), all_gbm (7g, 10w), best_of_family_xglm (8g, 10w), all_xglm (8g, 10w), best_of_family (10g, 10w), best_N (10g, 10w)]}]
# 05:31:31.604: AutoML job created: 2025.12.09 05:31:31.601
# 05:31:31.606: AutoML build started: 2025.12.09 05:31:31.606
# 05:31:31.607: AutoML: starting XGBoost_1_AutoML_2_20251209_53131 model training
#
#
# 05:31:33.104: New leader: XGBoost_1_AutoML_2_20251209_53131, rmse: 20.906668465922788
# 05:31:33.105: AutoML: starting GLM_1_AutoML_2_20251209_53131 model training
#
# █
# 05:31:33.330: New leader: GLM_1_AutoML_2_20251209_53131, rmse: 11.9493165970447
# 05:31:33.335: AutoML: starting GBM_1_AutoML_2_20251209_53131 model training
# 05:31:33.336: _min_rows param, The dataset size is too small to split for min_rows=100.0: must have at least 200.0 (weighted) rows, but have only 27.0.
# 05:31:33.338: AutoML: starting StackedEnsemble_BestOfFamily_1_AutoML_2_20251209_53131 model training
# 05:31:33.453: AutoML: starting XGBoost_2_AutoML_2_20251209_53131 model training
#
# ██
# 05:31:35.646: AutoML: starting DRF_1_AutoML_2_20251209_53131 model training
# 05:31:36.585: AutoML: starting GBM_2_AutoML_2_20251209_53131 model training
#
# █
# 05:31:37.16: AutoML: starting GBM_3_AutoML_2_20251209_53131 model training
# 05:31:37.460: AutoML: starting GBM_4_AutoML_2_20251209_53131 model training
# 05:31:37.900: AutoML: starting StackedEnsemble_BestOfFamily_2_AutoML_2_20251209_53131 model training
#
# ██
# 05:31:38.40: AutoML: starting StackedEnsemble_AllModels_1_AutoML_2_20251209_53131 model training
# 05:31:38.172: AutoML: starting XGBoost_3_AutoML_2_20251209_53131 model training
#
# ███
# 05:31:40.743: AutoML: starting XRT_1_AutoML_2_20251209_53131 model training
# 05:31:41.458: AutoML: starting GBM_5_AutoML_2_20251209_53131 model training
#
# ██
# 05:31:41.931: New leader: GBM_5_AutoML_2_20251209_53131, rmse: 11.520950332729246
# 05:31:41.935: AutoML: starting DeepLearning_1_AutoML_2_20251209_53131 model training
# 05:31:42.96: AutoML: starting StackedEnsemble_BestOfFamily_3_AutoML_2_20251209_53131 model training
# 05:31:42.214: AutoML: starting StackedEnsemble_AllModels_2_AutoML_2_20251209_53131 model training
# 05:31:42.341: AutoML: starting XGBoost_grid_1_AutoML_2_20251209_53131 hyperparameter search
#
# █████████████
# 05:32:07.413: New leader: XGBoost_grid_1_AutoML_2_20251209_53131_model_10, rmse: 10.949061196160926
#
# ██████████
# 05:32:33.46: AutoML: starting GBM_grid_1_AutoML_2_20251209_53131 hyperparameter search
# 05:32:34.53: New leader: GBM_grid_1_AutoML_2_20251209_53131_model_1, rmse: 10.379755493699445
#
# █
# 05:32:36.79: New leader: GBM_grid_1_AutoML_2_20251209_53131_model_8, rmse: 10.039176339075432
#
# █████
# 05:32:45.239: New leader: GBM_grid_1_AutoML_2_20251209_53131_model_66, rmse: 9.91187211305656
#
# ██████████
# 05:33:06.567: AutoML: starting DeepLearning_grid_1_AutoML_2_20251209_53131 hyperparameter search
#
# ████████
# 05:33:23.382: AutoML: starting StackedEnsemble_BestOfFamily_4_AutoML_2_20251209_53131 model training
#
# █
# 05:33:23.528: AutoML: starting StackedEnsemble_AllModels_3_AutoML_2_20251209_53131 model training
# 05:33:23.831: AutoML: starting DeepLearning_grid_2_AutoML_2_20251209_53131 hyperparameter search
#
# █
# 05:33:27.58: AutoML: starting DeepLearning_grid_3_AutoML_2_20251209_53131 hyperparameter search
#
# ██
# 05:33:30.209: AutoML: starting StackedEnsemble_AllModels_4_AutoML_2_20251209_53131 model training
#
#
# 05:33:30.492: Applying learning rate search on best XGBoost: XGBoost_grid_1_AutoML_2_20251209_53131_model_10
# 05:33:30.492: AutoML: starting XGBoost_lr_search_selection_AutoML_2_20251209_53131_select model training
#
# █| (done) 100%
#
# 05:33:31.520: Retraining best GBM with learning rate annealing: GBM_grid_1_AutoML_2_20251209_53131_model_66
# 05:33:31.520: AutoML: starting GBM_lr_annealing_selection_AutoML_2_20251209_53131_select_model model training
# 05:33:31.813: Actual modeling steps: [{XGBoost : [def_2 (1g, 10w)]}, {GLM : [def_1 (1g, 10w)]}, {StackedEnsemble : [best_of_family_1 (1g, 5w)]}, {XGBoost : [def_1 (2g, 10w)]}, {DRF : [def_1 (2g, 10w)]}, {GBM : [def_2 (2g, 10w), def_3 (2g, 10w), def_4 (2g, 10w)]}, {StackedEnsemble : [best_of_family_2 (2g, 5w), all_2 (2g, 10w)]}, {XGBoost : [def_3 (3g, 10w)]}, {DRF : [XRT (3g, 10w)]}, {GBM : [def_1 (3g, 10w)]}, {DeepLearning : [def_1 (3g, 10w)]}, {StackedEnsemble : [best_of_family_3 (3g, 5w), all_3 (3g, 10w)]}, {XGBoost : [grid_1 (4g, 90w)]}, {GBM : [grid_1 (4g, 60w)]}, {DeepLearning : [grid_1 (4g, 30w)]}, {StackedEnsemble : [best_of_family_4 (4g, 5w), all_4 (4g, 10w)]}, {DeepLearning : [grid_2 (5g, 30w), grid_3 (5g, 30w)]}, {StackedEnsemble : [all_5 (5g, 10w)]}, {XGBoost : [lr_search (6g, 30w)]}, {GBM : [lr_annealing (6g, 10w)]}]
# 05:33:31.813: AutoML build stopped: 2025.12.09 05:33:31.813
# 05:33:31.813: AutoML build done: built 150 models
# 05:33:31.813: AutoML duration:  2 min  0.207 sec
#
# model_id                                          rmse       mse      mae     rmsle    mean_residual_deviance
# GBM_grid_1_AutoML_2_20251209_53131_model_66    9.91187   98.2452  7.33897  0.357431                   98.2452
# GBM_grid_1_AutoML_2_20251209_53131_model_81   10.025    100.5     7.53199  0.361069                  100.5
# GBM_grid_1_AutoML_2_20251209_53131_model_8    10.0392   100.785   7.67355  0.36126                   100.785
# GBM_grid_1_AutoML_2_20251209_53131_model_137  10.0392   100.785   7.67355  0.36126                   100.785
# GBM_grid_1_AutoML_2_20251209_53131_model_24   10.0392   100.785   7.67355  0.36126                   100.785
# GBM_grid_1_AutoML_2_20251209_53131_model_85   10.1521   103.065   7.62807  0.361971                  103.065
# GBM_grid_1_AutoML_2_20251209_53131_model_190  10.2373   104.802   7.5932   0.358061                  104.802
# GBM_grid_1_AutoML_2_20251209_53131_model_63   10.242    104.899   7.66232  0.364389                  104.899
# GBM_grid_1_AutoML_2_20251209_53131_model_125  10.2798   105.673   7.76865  0.368338                  105.673
# GBM_grid_1_AutoML_2_20251209_53131_model_1    10.3798   107.739   7.91849  0.347401                  107.739
# [10 rows x 6 columns]
#
#   Best model for 'Avg_Resp_Left_Std': GBM_grid_1_AutoML_2_20251209_53131_model_66
#   Best -RMSE for 'Avg_Resp_Left_Std': -9.9119
#
# --- Evaluating 'Avg_Resp_Left_Hurst' as potential target ---
#   H2O determined type for 'Avg_Resp_Left_Hurst': real
#   Unique values in 'Avg_Resp_Left_Hurst': 30
#   Determined task type: regression
#   Fitting H2O AutoML for regression on 'Avg_Resp_Left_Hurst'...
# AutoML progress: |
# 05:33:33.376: Project: AutoML_3_20251209_53333
# 05:33:33.376: 5-fold cross-validation will be used.
# 05:33:33.376: Setting stopping tolerance adaptively based on the training frame: 0.05
# 05:33:33.376: Build control seed: 42
# 05:33:33.376: training frame: Frame key: AutoML_3_20251209_53333_training_py_23_sid_9690    cols: 10    rows: 27  chunks: 1    size: 2465  checksum: 926882371780204145
# 05:33:33.376: validation frame: NULL
# 05:33:33.376: leaderboard frame: NULL
# 05:33:33.377: blending frame: NULL
# 05:33:33.377: response column: Avg_Resp_Left_Hurst
# 05:33:33.377: fold column: null
# 05:33:33.377: weights column: null
# 05:33:33.378: Loading execution steps: [{XGBoost : [def_2 (1g, 10w), def_1 (2g, 10w), def_3 (3g, 10w), grid_1 (4g, 90w), lr_search (6g, 30w)]}, {GLM : [def_1 (1g, 10w)]}, {DRF : [def_1 (2g, 10w), XRT (3g, 10w)]}, {GBM : [def_5 (1g, 10w), def_2 (2g, 10w), def_3 (2g, 10w), def_4 (2g, 10w), def_1 (3g, 10w), grid_1 (4g, 60w), lr_annealing (6g, 10w)]}, {DeepLearning : [def_1 (3g, 10w), grid_1 (4g, 30w), grid_2 (5g, 30w), grid_3 (5g, 30w)]}, {completion : [resume_best_grids (10g, 60w)]}, {StackedEnsemble : [best_of_family_1 (1g, 5w), best_of_family_2 (2g, 5w), best_of_family_3 (3g, 5w), best_of_family_4 (4g, 5w), best_of_family_5 (5g, 5w), all_2 (2g, 10w), all_3 (3g, 10w), all_4 (4g, 10w), all_5 (5g, 10w), monotonic (6g, 10w), best_of_family_gbm (6g, 10w), all_gbm (7g, 10w), best_of_family_xglm (8g, 10w), all_xglm (8g, 10w), best_of_family (10g, 10w), best_N (10g, 10w)]}]
# 05:33:33.379: AutoML job created: 2025.12.09 05:33:33.375
# 05:33:33.379: AutoML build started: 2025.12.09 05:33:33.379
# 05:33:33.382: AutoML: starting XGBoost_1_AutoML_3_20251209_53333 model training
#
#
# 05:33:34.791: New leader: XGBoost_1_AutoML_3_20251209_53333, rmse: 0.5480247226723142
# 05:33:34.792: AutoML: starting GLM_1_AutoML_3_20251209_53333 model training
# 05:33:34.945: New leader: GLM_1_AutoML_3_20251209_53333, rmse: 0.5191767824079682
# 05:33:34.946: AutoML: starting GBM_1_AutoML_3_20251209_53333 model training
# 05:33:34.947: _min_rows param, The dataset size is too small to split for min_rows=100.0: must have at least 200.0 (weighted) rows, but have only 27.0.
# 05:33:34.947: AutoML: starting StackedEnsemble_BestOfFamily_1_AutoML_3_20251209_53333 model training
#
#
# 05:33:35.71: AutoML: starting XGBoost_2_AutoML_3_20251209_53333 model training
#
# ██
# 05:33:36.618: AutoML: starting DRF_1_AutoML_3_20251209_53333 model training
#
#
# 05:33:36.944: AutoML: starting GBM_2_AutoML_3_20251209_53333 model training
# 05:33:37.156: AutoML: starting GBM_3_AutoML_3_20251209_53333 model training
#
# █
# 05:33:37.430: AutoML: starting GBM_4_AutoML_3_20251209_53333 model training
# 05:33:37.647: AutoML: starting StackedEnsemble_BestOfFamily_2_AutoML_3_20251209_53333 model training
# 05:33:37.759: AutoML: starting StackedEnsemble_AllModels_1_AutoML_3_20251209_53333 model training
# 05:33:37.872: AutoML: starting XGBoost_3_AutoML_3_20251209_53333 model training
#
# ██████
# 05:33:40.758: New leader: XGBoost_3_AutoML_3_20251209_53333, rmse: 0.48570043176192823
# 05:33:40.759: AutoML: starting XRT_1_AutoML_3_20251209_53333 model training
#
# ██
# 05:33:41.556: AutoML: starting GBM_5_AutoML_3_20251209_53333 model training
# 05:33:42.58: AutoML: starting DeepLearning_1_AutoML_3_20251209_53333 model training
# 05:33:42.251: AutoML: starting StackedEnsemble_BestOfFamily_3_AutoML_3_20251209_53333 model training
# 05:33:42.369: AutoML: starting StackedEnsemble_AllModels_2_AutoML_3_20251209_53333 model training
#
# ██
# 05:33:42.483: AutoML: starting XGBoost_grid_1_AutoML_3_20251209_53333 hyperparameter search
#
# ████████
# 05:33:49.495: New leader: XGBoost_grid_1_AutoML_3_20251209_53333_model_4, rmse: 0.45791886075832666
#
# ████
# 05:34:00.521: New leader: XGBoost_grid_1_AutoML_3_20251209_53333_model_11, rmse: 0.4417539861312091
#
# █
# 05:34:05.534: New leader: XGBoost_grid_1_AutoML_3_20251209_53333_model_14, rmse: 0.44138588283721353
#
# █████████
# 05:34:33.852: AutoML: starting GBM_grid_1_AutoML_3_20251209_53333 hyperparameter search
#
# ███
# 05:34:40.905: AutoML: starting DeepLearning_grid_1_AutoML_3_20251209_53333 hyperparameter search
#
# ████████████████
# 05:35:15.971: AutoML: starting StackedEnsemble_BestOfFamily_4_AutoML_3_20251209_53333 model training
#
# █
# 05:35:16.141: AutoML: starting StackedEnsemble_AllModels_3_AutoML_3_20251209_53333 model training
# 05:35:16.441: AutoML: starting DeepLearning_grid_2_AutoML_3_20251209_53333 hyperparameter search
#
# ███
# 05:35:23.389: AutoML: starting DeepLearning_grid_3_AutoML_3_20251209_53333 hyperparameter search
#
# ███
# 05:35:30.210: AutoML: starting StackedEnsemble_BestOfFamily_5_AutoML_3_20251209_53333 model training
#
#
# 05:35:30.332: AutoML: starting StackedEnsemble_AllModels_4_AutoML_3_20251209_53333 model training
# 05:35:30.592: Applying learning rate search on best XGBoost: XGBoost_grid_1_AutoML_3_20251209_53333_model_14
# 05:35:30.592: AutoML: starting XGBoost_lr_search_selection_AutoML_3_20251209_53333_select model training
#
# █
# 05:35:32.627: Retraining best GBM with learning rate annealing: GBM_grid_1_AutoML_3_20251209_53333_model_47
# 05:35:32.627: AutoML: starting GBM_lr_annealing_selection_AutoML_3_20251209_53333_select_model model training
# 05:35:32.822: No base models, due to timeouts or the exclude_algos option. Skipping StackedEnsemble 'monotonic'.
# 05:35:32.823: AutoML: starting StackedEnsemble_BestOfFamily_6_AutoML_3_20251209_53333 model training
#
# █| (done) 100%
#
# 05:35:32.938: StackedEnsemble_BestOfFamily_6_AutoML_3_20251209_53333 [StackedEnsemble best_of_family_gbm (built with gbm metalearner, using top model from each algorithm type)] failed: java.lang.RuntimeException: water.exceptions.H2OModelBuilderIllegalArgumentException: Illegal argument(s) for GBM model: metalearner_gbm_StackedEnsemble_BestOfFamily_6_AutoML_3_20251209_53333.  Details: ERRR on field: _min_rows: The dataset size is too small to split for min_rows=10.0: must have at least 20.0 (weighted) rows, but have only 18.0.
#
# 05:35:32.942: AutoML: starting StackedEnsemble_AllModels_5_AutoML_3_20251209_53333 model training
# 05:35:33.61: StackedEnsemble_AllModels_5_AutoML_3_20251209_53333 [StackedEnsemble all_gbm (built with gbm metalearner, using all AutoML models)] failed: java.lang.RuntimeException: water.exceptions.H2OModelBuilderIllegalArgumentException: Illegal argument(s) for GBM model: metalearner_gbm_StackedEnsemble_AllModels_5_AutoML_3_20251209_53333.  Details: ERRR on field: _min_rows: The dataset size is too small to split for min_rows=10.0: must have at least 20.0 (weighted) rows, but have only 19.0.
#
# 05:35:33.64: AutoML: starting StackedEnsemble_BestOfFamily_7_AutoML_3_20251209_53333 model training
# 05:35:33.731: Actual modeling steps: [{XGBoost : [def_2 (1g, 10w)]}, {GLM : [def_1 (1g, 10w)]}, {StackedEnsemble : [best_of_family_1 (1g, 5w)]}, {XGBoost : [def_1 (2g, 10w)]}, {DRF : [def_1 (2g, 10w)]}, {GBM : [def_2 (2g, 10w), def_3 (2g, 10w), def_4 (2g, 10w)]}, {StackedEnsemble : [best_of_family_2 (2g, 5w), all_2 (2g, 10w)]}, {XGBoost : [def_3 (3g, 10w)]}, {DRF : [XRT (3g, 10w)]}, {GBM : [def_1 (3g, 10w)]}, {DeepLearning : [def_1 (3g, 10w)]}, {StackedEnsemble : [best_of_family_3 (3g, 5w), all_3 (3g, 10w)]}, {XGBoost : [grid_1 (4g, 90w)]}, {GBM : [grid_1 (4g, 60w)]}, {DeepLearning : [grid_1 (4g, 30w)]}, {StackedEnsemble : [best_of_family_4 (4g, 5w), all_4 (4g, 10w)]}, {DeepLearning : [grid_2 (5g, 30w), grid_3 (5g, 30w)]}, {StackedEnsemble : [best_of_family_5 (5g, 5w), all_5 (5g, 10w)]}, {XGBoost : [lr_search (6g, 30w)]}, {GBM : [lr_annealing (6g, 10w)]}, {StackedEnsemble : [best_of_family_xglm (8g, 10w)]}]
# 05:35:33.732: AutoML build stopped: 2025.12.09 05:35:33.731
# 05:35:33.732: AutoML build done: built 78 models
# 05:35:33.732: AutoML duration:  2 min  0.352 sec
#
# model_id                                                    rmse       mse       mae     rmsle    mean_residual_deviance
# XGBoost_grid_1_AutoML_3_20251209_53333_model_14         0.441386  0.194821  0.351655  0.206343                  0.194821
# XGBoost_grid_1_AutoML_3_20251209_53333_model_11         0.441754  0.195147  0.33278   0.210515                  0.195147
# XGBoost_grid_1_AutoML_3_20251209_53333_model_4          0.457919  0.20969   0.358898  0.213963                  0.20969
# StackedEnsemble_BestOfFamily_4_AutoML_3_20251209_53333  0.460851  0.212384  0.35961   0.217161                  0.212384
# StackedEnsemble_BestOfFamily_7_AutoML_3_20251209_53333  0.482994  0.233283  0.398708  0.227003                  0.233283
# XGBoost_grid_1_AutoML_3_20251209_53333_model_30         0.484762  0.234994  0.37822   0.22775                   0.234994
# XGBoost_3_AutoML_3_20251209_53333                       0.4857    0.235905  0.35998   0.232432                  0.235905
# XGBoost_grid_1_AutoML_3_20251209_53333_model_21         0.485903  0.236102  0.36124   0.229461                  0.236102
# XGBoost_grid_1_AutoML_3_20251209_53333_model_20         0.48932   0.239435  0.390734  0.226122                  0.239435
# StackedEnsemble_AllModels_2_AutoML_3_20251209_53333     0.489557  0.239666  0.391109  0.231354                  0.239666
# [10 rows x 6 columns]
#
#   Best model for 'Avg_Resp_Left_Hurst': XGBoost_grid_1_AutoML_3_20251209_53333_model_14
#   Best -RMSE for 'Avg_Resp_Left_Hurst': -0.4414
#
# --- Evaluating 'Avg_Resp_Right_Mean' as potential target ---
#   H2O determined type for 'Avg_Resp_Right_Mean': real
#   Unique values in 'Avg_Resp_Right_Mean': 30
#   Determined task type: regression
#   Fitting H2O AutoML for regression on 'Avg_Resp_Right_Mean'...
# AutoML progress: |
# 05:35:35.135: Project: AutoML_4_20251209_53535
# 05:35:35.135: 5-fold cross-validation will be used.
# 05:35:35.135: Setting stopping tolerance adaptively based on the training frame: 0.05
# 05:35:35.135: Build control seed: 42
# 05:35:35.135: training frame: Frame key: AutoML_4_20251209_53535_training_py_33_sid_9690    cols: 10    rows: 27  chunks: 1    size: 2465  checksum: 926882371780204145
# 05:35:35.135: validation frame: NULL
# 05:35:35.135: leaderboard frame: NULL
# 05:35:35.135: blending frame: NULL
# 05:35:35.135: response column: Avg_Resp_Right_Mean
# 05:35:35.135: fold column: null
# 05:35:35.135: weights column: null
# 05:35:35.136: Loading execution steps: [{XGBoost : [def_2 (1g, 10w), def_1 (2g, 10w), def_3 (3g, 10w), grid_1 (4g, 90w), lr_search (6g, 30w)]}, {GLM : [def_1 (1g, 10w)]}, {DRF : [def_1 (2g, 10w), XRT (3g, 10w)]}, {GBM : [def_5 (1g, 10w), def_2 (2g, 10w), def_3 (2g, 10w), def_4 (2g, 10w), def_1 (3g, 10w), grid_1 (4g, 60w), lr_annealing (6g, 10w)]}, {DeepLearning : [def_1 (3g, 10w), grid_1 (4g, 30w), grid_2 (5g, 30w), grid_3 (5g, 30w)]}, {completion : [resume_best_grids (10g, 60w)]}, {StackedEnsemble : [best_of_family_1 (1g, 5w), best_of_family_2 (2g, 5w), best_of_family_3 (3g, 5w), best_of_family_4 (4g, 5w), best_of_family_5 (5g, 5w), all_2 (2g, 10w), all_3 (3g, 10w), all_4 (4g, 10w), all_5 (5g, 10w), monotonic (6g, 10w), best_of_family_gbm (6g, 10w), all_gbm (7g, 10w), best_of_family_xglm (8g, 10w), all_xglm (8g, 10w), best_of_family (10g, 10w), best_N (10g, 10w)]}]
# 05:35:35.139: AutoML job created: 2025.12.09 05:35:35.135
# 05:35:35.139: AutoML build started: 2025.12.09 05:35:35.139
# 05:35:35.142: AutoML: starting XGBoost_1_AutoML_4_20251209_53535 model training
#
#
# 05:35:36.533: New leader: XGBoost_1_AutoML_4_20251209_53535, rmse: 28.15524710838898
# 05:35:36.534: AutoML: starting GLM_1_AutoML_4_20251209_53535 model training
# 05:35:36.709: New leader: GLM_1_AutoML_4_20251209_53535, rmse: 16.97353825941902
# 05:35:36.710: AutoML: starting GBM_1_AutoML_4_20251209_53535 model training
# 05:35:36.711: _min_rows param, The dataset size is too small to split for min_rows=100.0: must have at least 200.0 (weighted) rows, but have only 27.0.
# 05:35:36.711: AutoML: starting StackedEnsemble_BestOfFamily_1_AutoML_4_20251209_53535 model training
#
#
# 05:35:36.823: AutoML: starting XGBoost_2_AutoML_4_20251209_53535 model training
#
# ██
# 05:35:38.181: AutoML: starting DRF_1_AutoML_4_20251209_53535 model training
# 05:35:38.435: AutoML: starting GBM_2_AutoML_4_20251209_53535 model training
#
#
# 05:35:38.796: AutoML: starting GBM_3_AutoML_4_20251209_53535 model training
#
# █
# 05:35:39.117: AutoML: starting GBM_4_AutoML_4_20251209_53535 model training
# 05:35:39.389: AutoML: starting StackedEnsemble_BestOfFamily_2_AutoML_4_20251209_53535 model training
# 05:35:39.500: AutoML: starting StackedEnsemble_AllModels_1_AutoML_4_20251209_53535 model training
#
# █
# 05:35:39.609: AutoML: starting XGBoost_3_AutoML_4_20251209_53535 model training
#
# ██
# 05:35:40.914: AutoML: starting XRT_1_AutoML_4_20251209_53535 model training
#
# ██
# 05:35:41.405: AutoML: starting GBM_5_AutoML_4_20251209_53535 model training
# 05:35:41.843: AutoML: starting DeepLearning_1_AutoML_4_20251209_53535 model training
# 05:35:42.47: AutoML: starting StackedEnsemble_BestOfFamily_3_AutoML_4_20251209_53535 model training
# 05:35:42.177: AutoML: starting StackedEnsemble_AllModels_2_AutoML_4_20251209_53535 model training
#
# ████
# 05:35:42.309: AutoML: starting XGBoost_grid_1_AutoML_4_20251209_53535 hyperparameter search
#
# ███████████████████████
# 05:36:34.744: AutoML: starting GBM_grid_1_AutoML_4_20251209_53535 hyperparameter search
#
# █████
# 05:36:45.168: AutoML: starting DeepLearning_grid_1_AutoML_4_20251209_53535 hyperparameter search
#
# ███████████████
# 05:37:18.617: AutoML: starting StackedEnsemble_BestOfFamily_4_AutoML_4_20251209_53535 model training
# 05:37:18.741: AutoML: starting StackedEnsemble_AllModels_3_AutoML_4_20251209_53535 model training
# 05:37:18.986: AutoML: starting DeepLearning_grid_2_AutoML_4_20251209_53535 hyperparameter search
#
# ███
# 05:37:25.665: AutoML: starting DeepLearning_grid_3_AutoML_4_20251209_53535 hyperparameter search
#
# ███
# 05:37:32.230: AutoML: starting StackedEnsemble_AllModels_4_AutoML_4_20251209_53535 model training
#
#
# 05:37:32.481: Applying learning rate search on best XGBoost: XGBoost_grid_1_AutoML_4_20251209_53535_model_8
# 05:37:32.481: AutoML: starting XGBoost_lr_search_selection_AutoML_4_20251209_53535_select model training
#
# █
# 05:37:34.516: Retraining best GBM with learning rate annealing: GBM_grid_1_AutoML_4_20251209_53535_model_47
# 05:37:34.516: AutoML: starting GBM_lr_annealing_selection_AutoML_4_20251209_53535_select_model model training
# 05:37:34.737: New leader: GLM_1_AutoML_4_20251209_53535, rmse: 16.97353825941902
# 05:37:34.744: No base models, due to timeouts or the exclude_algos option. Skipping StackedEnsemble 'monotonic'.
# 05:37:34.745: AutoML: starting StackedEnsemble_BestOfFamily_5_AutoML_4_20251209_53535 model training
# 05:37:34.854: StackedEnsemble_BestOfFamily_5_AutoML_4_20251209_53535 [StackedEnsemble best_of_family_gbm (built with gbm metalearner, using top model from each algorithm type)] failed: java.lang.RuntimeException: water.exceptions.H2OModelBuilderIllegalArgumentException: Illegal argument(s) for GBM model: metalearner_gbm_StackedEnsemble_BestOfFamily_5_AutoML_4_20251209_53535.  Details: ERRR on field: _min_rows: The dataset size is too small to split for min_rows=10.0: must have at least 20.0 (weighted) rows, but have only 18.0.
#
# 05:37:34.860: AutoML: starting StackedEnsemble_AllModels_5_AutoML_4_20251209_53535 model training
# 05:37:34.976: StackedEnsemble_AllModels_5_AutoML_4_20251209_53535 [StackedEnsemble all_gbm (built with gbm metalearner, using all AutoML models)] failed: java.lang.RuntimeException: water.exceptions.H2OModelBuilderIllegalArgumentException: Illegal argument(s) for GBM model: metalearner_gbm_StackedEnsemble_AllModels_5_AutoML_4_20251209_53535.  Details: ERRR on field: _min_rows: The dataset size is too small to split for min_rows=10.0: must have at least 20.0 (weighted) rows, but have only 18.0.
#
# 05:37:34.982: AutoML: starting StackedEnsemble_BestOfFamily_6_AutoML_4_20251209_53535 model training
#
# █| (done) 100%
#
# 05:37:35.422: New leader: StackedEnsemble_BestOfFamily_6_AutoML_4_20251209_53535, rmse: 16.934845233241727
# 05:37:35.422: Actual modeling steps: [{XGBoost : [def_2 (1g, 10w)]}, {GLM : [def_1 (1g, 10w)]}, {StackedEnsemble : [best_of_family_1 (1g, 5w)]}, {XGBoost : [def_1 (2g, 10w)]}, {DRF : [def_1 (2g, 10w)]}, {GBM : [def_2 (2g, 10w), def_3 (2g, 10w), def_4 (2g, 10w)]}, {StackedEnsemble : [best_of_family_2 (2g, 5w), all_2 (2g, 10w)]}, {XGBoost : [def_3 (3g, 10w)]}, {DRF : [XRT (3g, 10w)]}, {GBM : [def_1 (3g, 10w)]}, {DeepLearning : [def_1 (3g, 10w)]}, {StackedEnsemble : [best_of_family_3 (3g, 5w), all_3 (3g, 10w)]}, {XGBoost : [grid_1 (4g, 90w)]}, {GBM : [grid_1 (4g, 60w)]}, {DeepLearning : [grid_1 (4g, 30w)]}, {StackedEnsemble : [best_of_family_4 (4g, 5w), all_4 (4g, 10w)]}, {DeepLearning : [grid_2 (5g, 30w), grid_3 (5g, 30w)]}, {StackedEnsemble : [all_5 (5g, 10w)]}, {XGBoost : [lr_search (6g, 30w)]}, {GBM : [lr_annealing (6g, 10w)]}, {StackedEnsemble : [best_of_family_xglm (8g, 10w)]}]
# 05:37:35.422: AutoML build stopped: 2025.12.09 05:37:35.422
# 05:37:35.422: AutoML build done: built 84 models
# 05:37:35.422: AutoML duration:  2 min  0.283 sec
#
# model_id                                                            rmse      mse      mae     rmsle    mean_residual_deviance
# StackedEnsemble_BestOfFamily_6_AutoML_4_20251209_53535           16.9348  286.789  14.5868  0.231167                   286.789
# GLM_1_AutoML_4_20251209_53535                                    16.9735  288.101  14.6176  0.233717                   288.101
# DeepLearning_grid_1_AutoML_4_20251209_53535_model_1              18.2036  331.371  15.2812  0.25379                    331.371
# StackedEnsemble_BestOfFamily_4_AutoML_4_20251209_53535           18.3442  336.509  15.6763  0.244888                   336.509
# StackedEnsemble_BestOfFamily_3_AutoML_4_20251209_53535           18.7361  351.042  15.8341  0.252365                   351.042
# GBM_lr_annealing_selection_AutoML_4_20251209_53535_select_model  18.8011  353.482  15.24    0.23783                    353.482
# StackedEnsemble_BestOfFamily_1_AutoML_4_20251209_53535           18.8188  354.146  15.9065  0.252706                   354.146
# XRT_1_AutoML_4_20251209_53535                                    18.9612  359.527  14.8919  0.256143                   359.527
# DeepLearning_grid_2_AutoML_4_20251209_53535_model_2              19.1913  368.307  15.8259  0.243118                   368.307
# GBM_grid_1_AutoML_4_20251209_53535_model_25                      19.2853  371.923  15.2646  0.245222                   371.923
# [10 rows x 6 columns]
#
#   Best model for 'Avg_Resp_Right_Mean': StackedEnsemble_BestOfFamily_6_AutoML_4_20251209_53535
#   Best -RMSE for 'Avg_Resp_Right_Mean': -16.9348
#
# --- Evaluating 'Avg_Resp_Right_Std' as potential target ---
#   H2O determined type for 'Avg_Resp_Right_Std': real
#   Unique values in 'Avg_Resp_Right_Std': 30
#   Determined task type: regression
#   Fitting H2O AutoML for regression on 'Avg_Resp_Right_Std'...
# AutoML progress: |
# 05:37:36.986: Project: AutoML_5_20251209_53736
# 05:37:36.986: 5-fold cross-validation will be used.
# 05:37:36.986: Setting stopping tolerance adaptively based on the training frame: 0.05
# 05:37:36.986: Build control seed: 42
# 05:37:36.986: training frame: Frame key: AutoML_5_20251209_53736_training_py_43_sid_9690    cols: 10    rows: 27  chunks: 1    size: 2465  checksum: 926882371780204145
# 05:37:36.986: validation frame: NULL
# 05:37:36.986: leaderboard frame: NULL
# 05:37:36.986: blending frame: NULL
# 05:37:36.986: response column: Avg_Resp_Right_Std
# 05:37:36.988: fold column: null
# 05:37:36.988: weights column: null
# 05:37:36.989: Loading execution steps: [{XGBoost : [def_2 (1g, 10w), def_1 (2g, 10w), def_3 (3g, 10w), grid_1 (4g, 90w), lr_search (6g, 30w)]}, {GLM : [def_1 (1g, 10w)]}, {DRF : [def_1 (2g, 10w), XRT (3g, 10w)]}, {GBM : [def_5 (1g, 10w), def_2 (2g, 10w), def_3 (2g, 10w), def_4 (2g, 10w), def_1 (3g, 10w), grid_1 (4g, 60w), lr_annealing (6g, 10w)]}, {DeepLearning : [def_1 (3g, 10w), grid_1 (4g, 30w), grid_2 (5g, 30w), grid_3 (5g, 30w)]}, {completion : [resume_best_grids (10g, 60w)]}, {StackedEnsemble : [best_of_family_1 (1g, 5w), best_of_family_2 (2g, 5w), best_of_family_3 (3g, 5w), best_of_family_4 (4g, 5w), best_of_family_5 (5g, 5w), all_2 (2g, 10w), all_3 (3g, 10w), all_4 (4g, 10w), all_5 (5g, 10w), monotonic (6g, 10w), best_of_family_gbm (6g, 10w), all_gbm (7g, 10w), best_of_family_xglm (8g, 10w), all_xglm (8g, 10w), best_of_family (10g, 10w), best_N (10g, 10w)]}]
# 05:37:36.990: AutoML job created: 2025.12.09 05:37:36.985
# 05:37:36.990: AutoML build started: 2025.12.09 05:37:36.990
# 05:37:36.990: AutoML: starting XGBoost_1_AutoML_5_20251209_53736 model training
#
# █
# 05:37:38.954: New leader: XGBoost_1_AutoML_5_20251209_53736, rmse: 8.773747989362514
# 05:37:38.955: AutoML: starting GLM_1_AutoML_5_20251209_53736 model training
# 05:37:39.83: New leader: GLM_1_AutoML_5_20251209_53736, rmse: 7.256561646227454
# 05:37:39.84: AutoML: starting GBM_1_AutoML_5_20251209_53736 model training
# 05:37:39.84: _min_rows param, The dataset size is too small to split for min_rows=100.0: must have at least 200.0 (weighted) rows, but have only 27.0.
# 05:37:39.85: AutoML: starting StackedEnsemble_BestOfFamily_1_AutoML_5_20251209_53736 model training
#
#
# 05:37:39.194: AutoML: starting XGBoost_2_AutoML_5_20251209_53736 model training
#
# █
# 05:37:40.811: AutoML: starting DRF_1_AutoML_5_20251209_53736 model training
# 05:37:40.993: New leader: DRF_1_AutoML_5_20251209_53736, rmse: 7.219101171348469
# 05:37:40.994: AutoML: starting GBM_2_AutoML_5_20251209_53736 model training
# 05:37:41.242: AutoML: starting GBM_3_AutoML_5_20251209_53736 model training
#
# █
# 05:37:41.484: AutoML: starting GBM_4_AutoML_5_20251209_53736 model training
# 05:37:41.681: AutoML: starting StackedEnsemble_BestOfFamily_2_AutoML_5_20251209_53736 model training
# 05:37:41.793: AutoML: starting StackedEnsemble_AllModels_1_AutoML_5_20251209_53736 model training
# 05:37:41.905: AutoML: starting XGBoost_3_AutoML_5_20251209_53736 model training
#
# ████
# 05:37:43.130: AutoML: starting XRT_1_AutoML_5_20251209_53736 model training
# 05:37:43.622: AutoML: starting GBM_5_AutoML_5_20251209_53736 model training
# 05:37:44.3: AutoML: starting DeepLearning_1_AutoML_5_20251209_53736 model training
# 05:37:44.148: AutoML: starting StackedEnsemble_BestOfFamily_3_AutoML_5_20251209_53736 model training
# 05:37:44.265: AutoML: starting StackedEnsemble_AllModels_2_AutoML_5_20251209_53736 model training
#
# ████
# 05:37:44.377: AutoML: starting XGBoost_grid_1_AutoML_5_20251209_53736 hyperparameter search
#
# ███████████████
# 05:38:03.421: New leader: XGBoost_grid_1_AutoML_5_20251209_53736_model_11, rmse: 6.821203087439994
#
# █████████
# 05:38:36.539: AutoML: starting GBM_grid_1_AutoML_5_20251209_53736 hyperparameter search
#
# ██████
# 05:38:48.692: New leader: GBM_grid_1_AutoML_5_20251209_53736_model_69, rmse: 6.794683811311868
#
# ██████████
# 05:39:11.158: AutoML: starting DeepLearning_grid_1_AutoML_5_20251209_53736 hyperparameter search
#
# ████████
# 05:39:28.498: AutoML: starting StackedEnsemble_BestOfFamily_4_AutoML_5_20251209_53736 model training
# 05:39:28.622: AutoML: starting StackedEnsemble_AllModels_3_AutoML_5_20251209_53736 model training
#
#
# 05:39:28.876: AutoML: starting DeepLearning_grid_2_AutoML_5_20251209_53736 hyperparameter search
#
# █
# 05:39:32.194: AutoML: starting DeepLearning_grid_3_AutoML_5_20251209_53736 hyperparameter search
#
# ██
# 05:39:35.494: AutoML: starting StackedEnsemble_AllModels_4_AutoML_5_20251209_53736 model training
#
#
# 05:39:35.767: Applying learning rate search on best XGBoost: XGBoost_grid_1_AutoML_5_20251209_53736_model_11
# 05:39:35.767: AutoML: starting XGBoost_lr_search_selection_AutoML_5_20251209_53736_select model training
#
#
# 05:39:36.843: Retraining best GBM with learning rate annealing: GBM_grid_1_AutoML_5_20251209_53736_model_69
# 05:39:36.843: AutoML: starting GBM_lr_annealing_selection_AutoML_5_20251209_53736_select_model model training
#
# █| (done) 100%
#
# 05:39:36.996: Actual modeling steps: [{XGBoost : [def_2 (1g, 10w)]}, {GLM : [def_1 (1g, 10w)]}, {StackedEnsemble : [best_of_family_1 (1g, 5w)]}, {XGBoost : [def_1 (2g, 10w)]}, {DRF : [def_1 (2g, 10w)]}, {GBM : [def_2 (2g, 10w), def_3 (2g, 10w), def_4 (2g, 10w)]}, {StackedEnsemble : [best_of_family_2 (2g, 5w), all_2 (2g, 10w)]}, {XGBoost : [def_3 (3g, 10w)]}, {DRF : [XRT (3g, 10w)]}, {GBM : [def_1 (3g, 10w)]}, {DeepLearning : [def_1 (3g, 10w)]}, {StackedEnsemble : [best_of_family_3 (3g, 5w), all_3 (3g, 10w)]}, {XGBoost : [grid_1 (4g, 90w)]}, {GBM : [grid_1 (4g, 60w)]}, {DeepLearning : [grid_1 (4g, 30w)]}, {StackedEnsemble : [best_of_family_4 (4g, 5w), all_4 (4g, 10w)]}, {DeepLearning : [grid_2 (5g, 30w), grid_3 (5g, 30w)]}, {StackedEnsemble : [all_5 (5g, 10w)]}, {XGBoost : [lr_search (6g, 30w)]}, {GBM : [lr_annealing (6g, 10w)]}]
# 05:39:36.996: AutoML build stopped: 2025.12.09 05:39:36.996
# 05:39:36.996: AutoML build done: built 166 models
# 05:39:36.996: AutoML duration:  2 min  0.006 sec
#
# model_id                                                   rmse      mse      mae     rmsle    mean_residual_deviance
# GBM_grid_1_AutoML_5_20251209_53736_model_69             6.79468  46.1677  5.92566  0.331493                   46.1677
# XGBoost_grid_1_AutoML_5_20251209_53736_model_11         6.8212   46.5288  5.59862  0.321594                   46.5288
# StackedEnsemble_BestOfFamily_4_AutoML_5_20251209_53736  6.84448  46.847   5.66579  0.341906                   46.847
# XGBoost_grid_1_AutoML_5_20251209_53736_model_16         6.85455  46.9848  5.87991  0.326974                   46.9848
# GBM_grid_1_AutoML_5_20251209_53736_model_151            6.91082  47.7595  5.61196  0.336542                   47.7595
# GBM_grid_1_AutoML_5_20251209_53736_model_20             6.94418  48.2216  5.57277  0.348986                   48.2216
# GBM_grid_1_AutoML_5_20251209_53736_model_51             6.99183  48.8857  5.69748  0.344602                   48.8857
# DeepLearning_grid_1_AutoML_5_20251209_53736_model_1     7.08975  50.2646  5.89971  0.362059                   50.2646
# GBM_grid_1_AutoML_5_20251209_53736_model_195            7.09396  50.3242  5.95423  0.356233                   50.3242
# GBM_grid_1_AutoML_5_20251209_53736_model_60             7.09457  50.333   6.14239  0.342368                   50.333
# [10 rows x 6 columns]
#
#   Best model for 'Avg_Resp_Right_Std': GBM_grid_1_AutoML_5_20251209_53736_model_69
#   Best -RMSE for 'Avg_Resp_Right_Std': -6.7947
#
# --- Evaluating 'Avg_Resp_Right_Hurst' as potential target ---
#   H2O determined type for 'Avg_Resp_Right_Hurst': real
#   Unique values in 'Avg_Resp_Right_Hurst': 30
#   Determined task type: regression
#   Fitting H2O AutoML for regression on 'Avg_Resp_Right_Hurst'...
# AutoML progress: |
# 05:39:38.649: Project: AutoML_6_20251209_53938
# 05:39:38.649: 5-fold cross-validation will be used.
# 05:39:38.649: Setting stopping tolerance adaptively based on the training frame: 0.05
# 05:39:38.649: Build control seed: 42
# 05:39:38.650: training frame: Frame key: AutoML_6_20251209_53938_training_py_53_sid_9690    cols: 10    rows: 27  chunks: 1    size: 2465  checksum: 926882371780204145
# 05:39:38.650: validation frame: NULL
# 05:39:38.650: leaderboard frame: NULL
# 05:39:38.650: blending frame: NULL
# 05:39:38.650: response column: Avg_Resp_Right_Hurst
# 05:39:38.650: fold column: null
# 05:39:38.650: weights column: null
# 05:39:38.650: Loading execution steps: [{XGBoost : [def_2 (1g, 10w), def_1 (2g, 10w), def_3 (3g, 10w), grid_1 (4g, 90w), lr_search (6g, 30w)]}, {GLM : [def_1 (1g, 10w)]}, {DRF : [def_1 (2g, 10w), XRT (3g, 10w)]}, {GBM : [def_5 (1g, 10w), def_2 (2g, 10w), def_3 (2g, 10w), def_4 (2g, 10w), def_1 (3g, 10w), grid_1 (4g, 60w), lr_annealing (6g, 10w)]}, {DeepLearning : [def_1 (3g, 10w), grid_1 (4g, 30w), grid_2 (5g, 30w), grid_3 (5g, 30w)]}, {completion : [resume_best_grids (10g, 60w)]}, {StackedEnsemble : [best_of_family_1 (1g, 5w), best_of_family_2 (2g, 5w), best_of_family_3 (3g, 5w), best_of_family_4 (4g, 5w), best_of_family_5 (5g, 5w), all_2 (2g, 10w), all_3 (3g, 10w), all_4 (4g, 10w), all_5 (5g, 10w), monotonic (6g, 10w), best_of_family_gbm (6g, 10w), all_gbm (7g, 10w), best_of_family_xglm (8g, 10w), all_xglm (8g, 10w), best_of_family (10g, 10w), best_N (10g, 10w)]}]
# 05:39:38.651: AutoML job created: 2025.12.09 05:39:38.649
# 05:39:38.651: AutoML build started: 2025.12.09 05:39:38.651
# 05:39:38.653: AutoML: starting XGBoost_1_AutoML_6_20251209_53938 model training
#
#
# 05:39:39.792: New leader: XGBoost_1_AutoML_6_20251209_53938, rmse: 0.49183418085640396
# 05:39:39.793: AutoML: starting GLM_1_AutoML_6_20251209_53938 model training
# 05:39:39.904: AutoML: starting GBM_1_AutoML_6_20251209_53938 model training
# 05:39:39.905: _min_rows param, The dataset size is too small to split for min_rows=100.0: must have at least 200.0 (weighted) rows, but have only 27.0.
# 05:39:39.905: AutoML: starting StackedEnsemble_BestOfFamily_1_AutoML_6_20251209_53938 model training
#
#
# 05:39:40.14: New leader: StackedEnsemble_BestOfFamily_1_AutoML_6_20251209_53938, rmse: 0.46462958618474065
# 05:39:40.15: AutoML: starting XGBoost_2_AutoML_6_20251209_53938 model training
#
# ██
# 05:39:41.214: AutoML: starting DRF_1_AutoML_6_20251209_53938 model training
# 05:39:41.444: New leader: DRF_1_AutoML_6_20251209_53938, rmse: 0.45663218443526715
# 05:39:41.445: AutoML: starting GBM_2_AutoML_6_20251209_53938 model training
# 05:39:41.585: AutoML: starting GBM_3_AutoML_6_20251209_53938 model training
#
#
# 05:39:41.762: AutoML: starting GBM_4_AutoML_6_20251209_53938 model training
# 05:39:41.897: AutoML: starting StackedEnsemble_BestOfFamily_2_AutoML_6_20251209_53938 model training
# 05:39:42.6: AutoML: starting StackedEnsemble_AllModels_1_AutoML_6_20251209_53938 model training
# 05:39:42.117: AutoML: starting XGBoost_3_AutoML_6_20251209_53938 model training
#
# ███
# 05:39:43.296: AutoML: starting XRT_1_AutoML_6_20251209_53938 model training
#
# ███
# 05:39:43.673: New leader: XRT_1_AutoML_6_20251209_53938, rmse: 0.4434497264691708
# 05:39:43.674: AutoML: starting GBM_5_AutoML_6_20251209_53938 model training
# 05:39:43.931: AutoML: starting DeepLearning_1_AutoML_6_20251209_53938 model training
# 05:39:44.38: AutoML: starting StackedEnsemble_BestOfFamily_3_AutoML_6_20251209_53938 model training
# 05:39:44.148: AutoML: starting StackedEnsemble_AllModels_2_AutoML_6_20251209_53938 model training
# 05:39:44.260: AutoML: starting XGBoost_grid_1_AutoML_6_20251209_53938 hyperparameter search
#
# ████████████████████████████
# 05:40:37.473: AutoML: starting GBM_grid_1_AutoML_6_20251209_53938 hyperparameter search
#
# ████
# 05:40:46.110: AutoML: starting DeepLearning_grid_1_AutoML_6_20251209_53938 hyperparameter search
#
# ███████████████
# 05:41:21.289: AutoML: starting StackedEnsemble_BestOfFamily_4_AutoML_6_20251209_53938 model training
# 05:41:21.445: AutoML: starting StackedEnsemble_AllModels_3_AutoML_6_20251209_53938 model training
# 05:41:21.706: AutoML: starting DeepLearning_grid_2_AutoML_6_20251209_53938 hyperparameter search
#
# ███
# 05:41:28.677: AutoML: starting DeepLearning_grid_3_AutoML_6_20251209_53938 hyperparameter search
#
# ███
# 05:41:35.479: AutoML: starting StackedEnsemble_AllModels_4_AutoML_6_20251209_53938 model training
# 05:41:35.637: Applying learning rate search on best XGBoost: XGBoost_grid_1_AutoML_6_20251209_53938_model_18
# 05:41:35.637: AutoML: starting XGBoost_lr_search_selection_AutoML_6_20251209_53938_select model training
#
# █
# 05:41:37.695: Retraining best GBM with learning rate annealing: GBM_grid_1_AutoML_6_20251209_53938_model_54
# 05:41:37.695: AutoML: starting GBM_lr_annealing_selection_AutoML_6_20251209_53938_select_model model training
#
#
# 05:41:37.976: New leader: XRT_1_AutoML_6_20251209_53938, rmse: 0.4434497264691708
# 05:41:37.984: No base models, due to timeouts or the exclude_algos option. Skipping StackedEnsemble 'monotonic'.
# 05:41:37.985: AutoML: starting StackedEnsemble_BestOfFamily_5_AutoML_6_20251209_53938 model training
# 05:41:38.91: StackedEnsemble_BestOfFamily_5_AutoML_6_20251209_53938 [StackedEnsemble best_of_family_gbm (built with gbm metalearner, using top model from each algorithm type)] failed: java.lang.RuntimeException: water.exceptions.H2OModelBuilderIllegalArgumentException: Illegal argument(s) for GBM model: metalearner_gbm_StackedEnsemble_BestOfFamily_5_AutoML_6_20251209_53938.  Details: ERRR on field: _min_rows: The dataset size is too small to split for min_rows=10.0: must have at least 20.0 (weighted) rows, but have only 18.0.
#
# 05:41:38.94: AutoML: starting StackedEnsemble_AllModels_5_AutoML_6_20251209_53938 model training
# 05:41:38.209: StackedEnsemble_AllModels_5_AutoML_6_20251209_53938 [StackedEnsemble all_gbm (built with gbm metalearner, using all AutoML models)] failed: java.lang.RuntimeException: water.exceptions.H2OModelBuilderIllegalArgumentException: Illegal argument(s) for GBM model: metalearner_gbm_StackedEnsemble_AllModels_5_AutoML_6_20251209_53938.  Details: ERRR on field: _min_rows: The dataset size is too small to split for min_rows=10.0: must have at least 20.0 (weighted) rows, but have only 18.0.
#
# 05:41:38.211: AutoML: starting StackedEnsemble_BestOfFamily_6_AutoML_6_20251209_53938 model training
#
# █| (done) 100%
#
# ...
# 05:45:42.994: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
#
# 05:45:44.128: New leader: XGBoost_1_AutoML_9_20251209_54542, rmse: 0.46869031462010025
# 05:45:44.129: AutoML: starting GLM_1_AutoML_9_20251209_54542 model training
# 05:45:44.129: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 05:45:44.215: New leader: GLM_1_AutoML_9_20251209_54542, rmse: 0.4542777113683189
# 05:45:44.216: AutoML: starting GBM_1_AutoML_9_20251209_54542 model training
# 05:45:44.216: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 05:45:44.216: _min_rows param, The dataset size is too small to split for min_rows=100.0: must have at least 200.0 (weighted) rows, but have only 27.0.
# 05:45:44.217: AutoML: starting StackedEnsemble_BestOfFamily_1_AutoML_9_20251209_54542 model training
# 05:45:44.217: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
#
# 05:45:44.327: New leader: StackedEnsemble_BestOfFamily_1_AutoML_9_20251209_54542, rmse: 0.44076869218668335
# 05:45:44.327: AutoML: starting XGBoost_2_AutoML_9_20251209_54542 model training
# 05:45:44.328: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# ██
# 05:45:45.814: AutoML: starting DRF_1_AutoML_9_20251209_54542 model training
# 05:45:45.814: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 05:45:45.957: AutoML: starting GBM_2_AutoML_9_20251209_54542 model training
# 05:45:45.957: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
#
# 05:45:46.200: New leader: GBM_2_AutoML_9_20251209_54542, rmse: 0.43850746326026047
# 05:45:46.201: AutoML: starting GBM_3_AutoML_9_20251209_54542 model training
# 05:45:46.201: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 05:45:46.474: AutoML: starting GBM_4_AutoML_9_20251209_54542 model training
# 05:45:46.474: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# █
# 05:45:46.713: New leader: GBM_4_AutoML_9_20251209_54542, rmse: 0.43651244793835686
# 05:45:46.714: AutoML: starting StackedEnsemble_BestOfFamily_2_AutoML_9_20251209_54542 model training
# 05:45:46.714: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 05:45:46.829: AutoML: starting StackedEnsemble_AllModels_1_AutoML_9_20251209_54542 model training
# 05:45:46.830: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 05:45:46.955: AutoML: starting XGBoost_3_AutoML_9_20251209_54542 model training
# 05:45:46.955: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# ███████
# 05:45:49.512: AutoML: starting XRT_1_AutoML_9_20251209_54542 model training
# 05:45:49.512: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 05:45:49.942: AutoML: starting GBM_5_AutoML_9_20251209_54542 model training
# 05:45:49.943: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# ██
# 05:45:50.332: AutoML: starting DeepLearning_1_AutoML_9_20251209_54542 model training
# 05:45:50.333: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 05:45:50.431: AutoML: starting StackedEnsemble_BestOfFamily_3_AutoML_9_20251209_54542 model training
# 05:45:50.431: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 05:45:50.542: AutoML: starting StackedEnsemble_AllModels_2_AutoML_9_20251209_54542 model training
# 05:45:50.542: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 05:45:50.668: AutoML: starting XGBoost_grid_1_AutoML_9_20251209_54542 hyperparameter search
#
# █████████████████
# 05:46:28.699: AutoML: starting GBM_grid_1_AutoML_9_20251209_54542 hyperparameter search
# 05:46:29.712: New leader: GBM_grid_1_AutoML_9_20251209_54542_model_2, rmse: 0.4122107317742054
#
# ██
# 05:46:33.746: New leader: GBM_grid_1_AutoML_9_20251209_54542_model_20, rmse: 0.40444380032523986
#
# █████
# 05:46:45.122: AutoML: starting DeepLearning_grid_1_AutoML_9_20251209_54542 hyperparameter search
#
# ██████████████████
# 05:47:23.910: AutoML: starting StackedEnsemble_BestOfFamily_4_AutoML_9_20251209_54542 model training
# 05:47:23.911: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 05:47:24.54: AutoML: starting StackedEnsemble_AllModels_3_AutoML_9_20251209_54542 model training
# 05:47:24.55: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 05:47:24.306: AutoML: starting DeepLearning_grid_2_AutoML_9_20251209_54542 hyperparameter search
#
# ███
# 05:47:31.971: AutoML: starting DeepLearning_grid_3_AutoML_9_20251209_54542 hyperparameter search
#
# ████
# 05:47:39.349: AutoML: starting StackedEnsemble_BestOfFamily_5_AutoML_9_20251209_54542 model training
# 05:47:39.349: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 05:47:39.465: AutoML: starting StackedEnsemble_AllModels_4_AutoML_9_20251209_54542 model training
# 05:47:39.466: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 05:47:39.596: Applying learning rate search on best XGBoost: XGBoost_grid_1_AutoML_9_20251209_54542_model_22
# 05:47:39.597: AutoML: starting XGBoost_lr_search_selection_AutoML_9_20251209_54542_select model training
#
# █
# 05:47:41.680: Retraining best GBM with learning rate annealing: GBM_grid_1_AutoML_9_20251209_54542_model_20
# 05:47:41.680: AutoML: starting GBM_lr_annealing_selection_AutoML_9_20251209_54542_select_model model training
# 05:47:41.680: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 05:47:41.861: No base models, due to timeouts or the exclude_algos option. Skipping StackedEnsemble 'monotonic'.
# 05:47:41.862: AutoML: starting StackedEnsemble_BestOfFamily_6_AutoML_9_20251209_54542 model training
# 05:47:41.862: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 05:47:41.968: StackedEnsemble_BestOfFamily_6_AutoML_9_20251209_54542 [StackedEnsemble best_of_family_gbm (built with gbm metalearner, using top model from each algorithm type)] failed: java.lang.RuntimeException: water.exceptions.H2OModelBuilderIllegalArgumentException: Illegal argument(s) for GBM model: metalearner_gbm_StackedEnsemble_BestOfFamily_6_AutoML_9_20251209_54542.  Details: ERRR on field: _min_rows: The dataset size is too small to split for min_rows=10.0: must have at least 20.0 (weighted) rows, but have only 18.0.
#
# 05:47:41.971: AutoML: starting StackedEnsemble_AllModels_5_AutoML_9_20251209_54542 model training
# 05:47:41.972: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 05:47:42.86: StackedEnsemble_AllModels_5_AutoML_9_20251209_54542 [StackedEnsemble all_gbm (built with gbm metalearner, using all AutoML models)] failed: java.lang.RuntimeException: water.exceptions.H2OModelBuilderIllegalArgumentException: Illegal argument(s) for GBM model: metalearner_gbm_StackedEnsemble_AllModels_5_AutoML_9_20251209_54542.  Details: ERRR on field: _min_rows: The dataset size is too small to split for min_rows=10.0: must have at least 20.0 (weighted) rows, but have only 19.0.
#
# 05:47:42.90: AutoML: starting StackedEnsemble_BestOfFamily_7_AutoML_9_20251209_54542 model training
# 05:47:42.90: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
#
# 05:47:42.314: AutoML: starting StackedEnsemble_AllModels_6_AutoML_9_20251209_54542 model training
# 05:47:42.314: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 05:47:42.545: AutoML: starting GBM_grid_1_AutoML_9_20251209_54542 hyperparameter search
# 05:47:42.756: AutoML: starting DeepLearning_grid_3_AutoML_9_20251209_54542 hyperparameter search
#
# █| (done) 100%
#
# 05:47:43.337: Actual modeling steps: [{XGBoost : [def_2 (1g, 10w)]}, {GLM : [def_1 (1g, 10w)]}, {StackedEnsemble : [best_of_family_1 (1g, 5w)]}, {XGBoost : [def_1 (2g, 10w)]}, {DRF : [def_1 (2g, 10w)]}, {GBM : [def_2 (2g, 10w), def_3 (2g, 10w), def_4 (2g, 10w)]}, {StackedEnsemble : [best_of_family_2 (2g, 5w), all_2 (2g, 10w)]}, {XGBoost : [def_3 (3g, 10w)]}, {DRF : [XRT (3g, 10w)]}, {GBM : [def_1 (3g, 10w)]}, {DeepLearning : [def_1 (3g, 10w)]}, {StackedEnsemble : [best_of_family_3 (3g, 5w), all_3 (3g, 10w)]}, {XGBoost : [grid_1 (4g, 90w)]}, {GBM : [grid_1 (4g, 60w)]}, {DeepLearning : [grid_1 (4g, 30w)]}, {StackedEnsemble : [best_of_family_4 (4g, 5w), all_4 (4g, 10w)]}, {DeepLearning : [grid_2 (5g, 30w), grid_3 (5g, 30w)]}, {StackedEnsemble : [best_of_family_5 (5g, 5w), all_5 (5g, 10w)]}, {XGBoost : [lr_search (6g, 30w)]}, {GBM : [lr_annealing (6g, 10w)]}, {StackedEnsemble : [best_of_family_xglm (8g, 10w), all_xglm (8g, 10w)]}, {completion : [resume_best_grids (10g, 60w)]}]
# 05:47:43.337: AutoML build stopped: 2025.12.09 05:47:43.337
# 05:47:43.337: AutoML build done: built 100 models
# 05:47:43.338: AutoML duration:  2 min  0.344 sec
#
# model_id                                         rmse       mse       mae     rmsle    mean_residual_deviance
# GBM_grid_1_AutoML_9_20251209_54542_model_20  0.404444  0.163575  0.320167  0.278612                  0.163575
# GBM_grid_1_AutoML_9_20251209_54542_model_2   0.412211  0.169918  0.328233  0.292449                  0.169918
# GBM_grid_1_AutoML_9_20251209_54542_model_9   0.413183  0.17072   0.318967  0.288937                  0.17072
# GBM_grid_1_AutoML_9_20251209_54542_model_90  0.416065  0.17311   0.342519  0.290581                  0.17311
# GBM_grid_1_AutoML_9_20251209_54542_model_13  0.416788  0.173712  0.321734  0.294216                  0.173712
# GBM_grid_1_AutoML_9_20251209_54542_model_28  0.417753  0.174518  0.332078  0.293964                  0.174518
# GBM_grid_1_AutoML_9_20251209_54542_model_56  0.420685  0.176976  0.327894  0.297373                  0.176976
# GBM_grid_1_AutoML_9_20251209_54542_model_4   0.423356  0.17923   0.330017  0.294583                  0.17923
# GBM_grid_1_AutoML_9_20251209_54542_model_21  0.423585  0.179424  0.341956  0.293994                  0.179424
# GBM_grid_1_AutoML_9_20251209_54542_model_92  0.424203  0.179949  0.33746   0.293787                  0.179949
# [10 rows x 6 columns]
#
#   Best model for 'pain_type': GBM_grid_1_AutoML_9_20251209_54542_model_20
#   Best -RMSE for 'pain_type': -0.4044
#
# --- Summary of H2O AutoML Performance for Potential Targets ---
#   pain_type                 | -RMSE           | -0.4044 | Task: regression
#   Avg_Resp_Left_Hurst       | -RMSE           | -0.4414 | Task: regression
#   Avg_Resp_Right_Hurst      | -RMSE           | -0.4434 | Task: regression
#   Avg_Resp_DTW_Cluster      | -RMSE           | -0.5484 | Task: regression
#   Inh_Thresh_DTW_Cluster    | -RMSE           | -1.0675 | Task: regression
#   Avg_Resp_Right_Std        | -RMSE           | -6.7947 | Task: regression
#   Avg_Resp_Left_Std         | -RMSE           | -9.9119 | Task: regression
#   Avg_Resp_Right_Mean       | -RMSE           | -16.9348 | Task: regression
#   Avg_Resp_Left_Mean        | -RMSE           | -28.3268 | Task: regression
#
# Best target column based on H2O AutoML performance: 'pain_type' with -RMSE: -0.4044 (Task: regression)
#
# --- Leaderboard for the Best Target ('pain_type') ---
# model_id                                         rmse       mse       mae     rmsle    mean_residual_deviance
# GBM_grid_1_AutoML_9_20251209_54542_model_20  0.404444  0.163575  0.320167  0.278612                  0.163575
# GBM_grid_1_AutoML_9_20251209_54542_model_2   0.412211  0.169918  0.328233  0.292449                  0.169918
# GBM_grid_1_AutoML_9_20251209_54542_model_9   0.413183  0.17072   0.318967  0.288937                  0.17072
# GBM_grid_1_AutoML_9_20251209_54542_model_90  0.416065  0.17311   0.342519  0.290581                  0.17311
# GBM_grid_1_AutoML_9_20251209_54542_model_13  0.416788  0.173712  0.321734  0.294216                  0.173712
# GBM_grid_1_AutoML_9_20251209_54542_model_28  0.417753  0.174518  0.332078  0.293964                  0.174518
# GBM_grid_1_AutoML_9_20251209_54542_model_56  0.420685  0.176976  0.327894  0.297373                  0.176976
# GBM_grid_1_AutoML_9_20251209_54542_model_4   0.423356  0.17923   0.330017  0.294583                  0.17923
# GBM_grid_1_AutoML_9_20251209_54542_model_21  0.423585  0.179424  0.341956  0.293994                  0.179424
# GBM_grid_1_AutoML_9_20251209_54542_model_92  0.424203  0.179949  0.33746   0.293787                  0.179949
# [111 rows x 6 columns]
#
#
# Shutting down H2O...
# H2O session _sid_9690 closed.
#
# Done.

# %% [markdown]
# # Shapley values
# Initialize H2O, load `df_clean` into an H2OFrame, retrieve the best model using `best_lb`, calculate Shapley values for the best model on the training data, and then visualize the feature importance using these Shapley values.

# %%
# !pip install shap --quiet

# %% [markdown]
# **Reasoning**:
# Re-initialize H2O and import the shap library as requested by the subtask.

# %%
#import h2o
import shap

print("Re-initializing H2O...")
h2o.init()
# Out:
# Re-initializing H2O...
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "17.0.16" 2025-07-15; OpenJDK Runtime Environment (build 17.0.16+8-Ubuntu-0ubuntu122.04.1); OpenJDK 64-Bit Server VM (build 17.0.16+8-Ubuntu-0ubuntu122.04.1, mixed mode, sharing)
#   Starting server from /usr/local/lib/python3.12/dist-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmpo_rtkkyt
#   JVM stdout: /tmp/tmpo_rtkkyt/h2o_unknownUser_started_from_python.out
#   JVM stderr: /tmp/tmpo_rtkkyt/h2o_unknownUser_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  -----------------------------------------------------------------------------------------
# H2O_cluster_uptime:         03 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.46.0.9
# H2O_cluster_version_age:    14 days, 13 hours and 20 minutes
# H2O_cluster_name:           H2O_from_python_unknownUser_1g55dz
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    3.168 Gb
# H2O_cluster_total_cores:    2
# H2O_cluster_allowed_cores:  2
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null, "colab_language_server": "/usr/colab/bin/language_service"}
# H2O_internal_security:      False
# Python_version:             3.12.12 final
# --------------------------  -----------------------------------------------------------------------------------------

# %%
# Re-create H2OFrame for the current session
h2o_df_current_session = h2o.H2OFrame(df_clean)

# Get the best target column and task from the previous analysis
y_col = best_target_col
x_cols = [col for col in feature_columns if col != y_col]
task = best_task

# Ensure the target column is correctly typed for the task in the current H2OFrame
if task == 'classification':
    h2o_df_current_session[y_col] = h2o_df_current_session[y_col].asfactor()

print(f"Re-running AutoML for target '{y_col}' (Task: {task}) to obtain a valid model in the current H2O session...")

# Re-run AutoML for the best target column in the current session
aml_current_session = H2OAutoML(
    max_runtime_secs=60, # Reduced runtime to quickly get a model for SHAP
    seed=42,
    verbosity='warn'
)
aml_current_session.train(x=x_cols, y=y_col, training_frame=h2o_df_current_session)

# Get the new best model from the current session's AutoML leaderboard
current_best_lb = aml_current_session.leaderboard
model_id = current_best_lb[0, 'model_id']
best_model = h2o.get_model(model_id)

# Convert feature data to H2OFrame for SHAP, excluding the target column
h2o_feature_frame = h2o.H2OFrame(df_clean[[col for col in feature_columns if col != y_col]])

print(f"Loaded best model from current session: {best_model.model_id}")
print("Feature data converted to H2OFrame.")
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Re-running AutoML for target 'pain_type' (Task: regression) to obtain a valid model in the current H2O session...
# AutoML progress: |
# 05:48:56.417: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# ██
# 05:48:59.589: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
#
# 05:49:00.428: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 05:49:00.428: _min_rows param, The dataset size is too small to split for min_rows=100.0: must have at least 200.0 (weighted) rows, but have only 31.0.
# 05:49:00.443: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 05:49:00.703: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# █████
# 05:49:04.740: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# ██
# 05:49:07.59: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# ███
# 05:49:08.960: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 05:49:09.935: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# █
# 05:49:10.446: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 05:49:10.581: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 05:49:10.717: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# ██
# 05:49:12.518: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# █
# 05:49:13.616: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# ██
# 05:49:14.546: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 05:49:15.109: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
# 05:49:15.336: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# █████████████████████████████████████████
# 05:49:53.322: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# █
# 05:49:53.467: _response param, We have detected that your response column has only 2 unique values (0/1). If you wish to train a binary model instead of a regression model, convert your target column to categorical before training.
#
# ███| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Loaded best model from current session: GBM_grid_1_AutoML_1_20251209_54856_model_21
# Feature data converted to H2OFrame.

# %% [markdown]
# **Reasoning**:
# Now that the H2O model and feature data are ready, I will calculate SHAP values using `shap.TreeExplainer` for the first two data points from the `h2o_feature_frame`. This will provide the necessary values to create individual force plots as requested by the subtask.

# %%
contributions = best_model.predict_contributions(h2o_feature_frame)

# Convert the H2OFrame contributions to a pandas DataFrame
contributions_df = contributions.as_data_frame()

# Extract SHAP values (all columns except 'BiasTerm')
shap_values_individual = contributions_df.drop(columns=['BiasTerm']).values

# The 'BiasTerm' represents the expected value (base value)
# We take the first value as expected_value is typically constant for a given model or dataset
expected_value = contributions_df['BiasTerm'].iloc[0]

print(f"SHAP values calculated using H2O's predict_contributions.")
print(f"Calculated SHAP values for {len(shap_values_individual)} instances.")
print(f"Expected (base) value: {expected_value}")
# Out:
# contributions progress: |████████████████████████████████████████████████████████| (done) 100%
# SHAP values calculated using H2O's predict_contributions.
# Calculated SHAP values for 31 instances.
# Expected (base) value: 0.3115666210651397

# %%
import matplotlib.pyplot as plt

# Get the feature names directly from the h2o_feature_frame for consistent labeling
feature_names = h2o_feature_frame.col_names

# Select the first two instances for plotting
instance_1_shap_values = shap_values_individual[0]
instance_1_features = df_clean[[col for col in feature_columns if col != y_col]].iloc[0]

instance_2_shap_values = shap_values_individual[1]
instance_2_features = df_clean[[col for col in feature_columns if col != y_col]].iloc[1]

print("Generating SHAP force plot for instance 1...")
shap.force_plot(expected_value, instance_1_shap_values, instance_1_features, matplotlib=True, show=False)
plt.title("SHAP Force Plot for Instance 1")
plt.tight_layout()
plt.show()

print("Generating SHAP force plot for instance 2...")
shap.force_plot(expected_value, instance_2_shap_values, instance_2_features, matplotlib=True, show=False)
plt.title("SHAP Force Plot for Instance 2")
plt.tight_layout()
plt.show()
# Out:
# Generating SHAP force plot for instance 1...
# Generating SHAP force plot for instance 2...

# %% [markdown]
# # LightAutoML

# %%
# !pip install -U lightautoml -q
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.5/412.5 kB 29.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.1/216.1 kB 17.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 8.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.5/309.5 kB 21.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 116.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.6/223.6 MB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.5/64.5 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 18.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.8/107.8 kB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 83.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 6.9 MB/s eta 0:00:00
#   Building wheel for json2html (setup.py) ... done

# %%
# Импорт библиотек для auto ml

from lightautoml.automl.presets.tabular_presets import TabularAutoML
from lightautoml.tasks import Task
from lightautoml.report.report_deco import ReportDeco, ReportDecoUtilized
from lightautoml.addons.tabular_interpretation import SSWARM

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split

import torch
# Out:
# WARNING:lightautoml.utils.installation:'nlp' extra dependency package 'fasttext-numpy2' isn't installed. Look at README.md in repo 'LightAutoML' for installation instructions.

# %%
df = df.fillna(2.0)

# %%
N_THREADS = 4 #number of vCPUs for LightAutoML model creation
N_FOLDS = 2 # number of folds in LightAutoML inner CV
#All models that are trained during the cross-validation loop
#on different folds are then saved for the inference phase.
#Inference on new data is made by averaging models from all train folds.

RANDOM_STATE = 42 # fixed random state for various reasons
TEST_SIZE = 0.2 # Test size for metric check
TIMEOUT = 100 # Time in seconds for automl run
TARGET_NAME = 'pain_type' # Target column name

np.random.seed(RANDOM_STATE)
torch.set_num_threads(N_THREADS)

autoML_df = df

# %%
autoML_df = autoML_df.dropna()

# %%
autoML_df = autoML_df.drop(['patient_id'], axis=1)

# %%
train_data, test_data = train_test_split(
    autoML_df,
    test_size=TEST_SIZE,
    stratify=autoML_df[TARGET_NAME],
    random_state=RANDOM_STATE
)

print(f'Data is splitted. Parts sizes: train_data = {train_data.shape}, test_data = {test_data.shape}')

train_data.head()
# Out:
# Data is splitted. Parts sizes: train_data = (48, 9), test_data = (13, 9)
#     Avg_Resp_Left_Mean  Avg_Resp_Left_Std  Avg_Resp_Left_Hurst  \
# 3            73.540167          23.046395             0.802684
# 54          150.051310          56.838459             1.833215
# 48          149.761161          53.176081             2.036485
# 10           59.629250          19.727175             1.036355
# 16           92.293414          24.407128             1.388527
#
#     Avg_Resp_Right_Mean  Avg_Resp_Right_Std  Avg_Resp_Right_Hurst  \
# 3             64.819444           13.978575              1.351294
# 54            82.788194           21.987831              1.024580
# 48           121.672768           21.297929              0.734508
# 10           124.957870           41.943004              0.965765
# 16            53.988750           25.558816              0.826390
#
#     Avg_Resp_DTW_Cluster  Inh_Thresh_DTW_Cluster  pain_type
# 3                    1.0                       1        2.0
# 54                   2.0                       2        0.0
# 48                   2.0                       2        0.0
# 10                   3.0                       2        2.0
# 16                   1.0                       0        2.0

# %%
#The following task types are available:
#'binary' - for binary classification.
#'reg’ - for regression.
#‘multiclass’ - for multiclass classification.
#'multi:reg - for multiple regression.
#'multilabel' - for multi-label classification.

task = Task('multiclass')


roles = {
    'target': TARGET_NAME
    #'category': TARGET_NAME
    #'drop': ['name of column']
}

# %%
automl = TabularAutoML(
    task = task,
    timeout = TIMEOUT,
    cpu_limit = N_THREADS,
    reader_params = {'n_jobs': N_THREADS, 'cv': N_FOLDS, 'random_state': RANDOM_STATE},
)

# %%
out_of_fold_predictions = automl.fit_predict(train_data, roles = roles, verbose = 2)
# Out:
# [06:12:04] Stdout logging level is INFO2.
# INFO:lightautoml.automl.presets.base:Stdout logging level is INFO2.
# [06:12:04] Task: multiclass
# INFO:lightautoml.automl.presets.base:Task: multiclass
# [06:12:04] Start automl preset with listed constraints:
# INFO:lightautoml.automl.presets.base:Start automl preset with listed constraints:
# [06:12:04] - time: 100.00 seconds
# INFO:lightautoml.automl.presets.base:- time: 100.00 seconds
# [06:12:04] - CPU: 4 cores
# INFO:lightautoml.automl.presets.base:- CPU: 4 cores
# [06:12:04] - memory: 16 GB
# INFO:lightautoml.automl.presets.base:- memory: 16 GB
# [06:12:04] Train data shape: (48, 9)
# INFO:lightautoml.reader.base:Train data shape: (48, 9)
#
# INFO3:lightautoml.reader.base:Feats was rejected during automatic roles guess: []
# [06:12:13] Layer 1 train process start. Time left 90.72 secs
# INFO:lightautoml.automl.base:Layer 1 train process start. Time left 90.72 secs
# [06:12:13] Start fitting Lvl_0_Pipe_0_Mod_0_LinearL2 ...
# INFO:lightautoml.ml_algo.base:Start fitting Lvl_0_Pipe_0_Mod_0_LinearL2 ...
# DEBUG:lightautoml.ml_algo.base:Training params: {'tol': 1e-06, 'max_iter': 100, 'cs': [1e-05, 5e-05, 0.0001, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1, 5, 10, 50, 100, 500, 1000, 5000, 10000, 50000, 100000], 'early_stopping': 2, 'categorical_idx': [0, 1], 'embed_sizes': array([ 5, 11], dtype=int32), 'data_size': 14}
# [06:12:13] ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1e-05 score = -1.015498572757575
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5e-05 score = -1.0153265354320486
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0001 score = -1.0151192710871708
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0005 score = -1.013630310996074
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.001 score = -1.0121681615679694
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.005 score = -1.011628931370353
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.01 score = -1.0217056782579255
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.05 score = -1.1449453210306642
# [06:12:14] ===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1e-05 score = -1.0283967375804315
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5e-05 score = -1.0282206723931733
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0001 score = -1.0280008921932884
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0005 score = -1.0263422080179934
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.001 score = -1.0245870246356261
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.005 score = -1.020449674130725
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.01 score = -1.0279762668848909
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.05 score = -1.1657022650126387
# [06:12:15] Fitting Lvl_0_Pipe_0_Mod_0_LinearL2 finished. score = -1.0160393027505388
# INFO:lightautoml.ml_algo.base:Fitting Lvl_0_Pipe_0_Mod_0_LinearL2 finished. score = -1.0160393027505388
# [06:12:15] Lvl_0_Pipe_0_Mod_0_LinearL2 fitting and predicting completed
# INFO:lightautoml.ml_algo.base:Lvl_0_Pipe_0_Mod_0_LinearL2 fitting and predicting completed
# [06:12:15] Time left 88.64 secs
# INFO:lightautoml.automl.base:Time left 88.64 secs
#
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.01565
# [06:12:15] Selector_LightGBM fitting and predicting completed
# INFO:lightautoml.ml_algo.base:Selector_LightGBM fitting and predicting completed
# [06:12:15] Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
# INFO:lightautoml.ml_algo.base:Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
# DEBUG:lightautoml.ml_algo.base:Training params: {'task': 'train', 'learning_rate': 0.01, 'num_leaves': 16, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'bagging_freq': 1, 'max_depth': -1, 'verbosity': -1, 'reg_alpha': 1, 'reg_lambda': 0.0, 'min_split_gain': 0.0, 'zero_as_missing': False, 'num_threads': 2, 'max_bin': 255, 'min_data_in_bin': 3, 'num_trees': 3000, 'early_stopping_rounds': 200, 'random_state': 42, 'verbose_eval': 100}
# [06:12:15] ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.01565
# [06:12:15] ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's multi_logloss: 1.0283
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's multi_logloss: 1.0283
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.0283
# [06:12:15] Fitting Lvl_0_Pipe_1_Mod_0_LightGBM finished. score = -1.021973776790689
# INFO:lightautoml.ml_algo.base:Fitting Lvl_0_Pipe_1_Mod_0_LightGBM finished. score = -1.021973776790689
# [06:12:15] Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# INFO:lightautoml.ml_algo.base:Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# [06:12:15] Start hyperparameters optimization for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM ... Time budget is 17.43 secs
# INFO:lightautoml.ml_algo.tuning.optuna:Start hyperparameters optimization for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM ... Time budget is 17.43 secs
# Optimization Progress:   0%|          | 0/101 [00:00<?, ?it/s]INFO:optuna.storages._in_memory:A new study created in memory with name: no-name-53309e27-fa83-46e7-99dd-fa89cf7275af
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.01565
# INFO:optuna.study.study:Trial 0 finished with value: -1.015648925512444 and parameters: {'feature_fraction': 0.6872700594236812, 'num_leaves': 244, 'bagging_fraction': 0.8659969709057025, 'min_sum_hessian_in_leaf': 0.24810409748678125, 'reg_alpha': 2.5361081166471375e-07, 'reg_lambda': 2.5348407664333426e-07}. Best is trial 0 with value: -1.015648925512444.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 1 with hyperparameters {'feature_fraction': 0.6872700594236812, 'num_leaves': 244, 'bagging_fraction': 0.8659969709057025, 'min_sum_hessian_in_leaf': 0.24810409748678125, 'reg_alpha': 2.5361081166471375e-07, 'reg_lambda': 2.5348407664333426e-07} scored -1.015648925512444 in 0:00:00.023550
# Optimization Progress:   0%|          | 0/101 [00:00<?, ?it/s, best_trial=0, best_value=-1.02]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.01565
# INFO:optuna.study.study:Trial 1 finished with value: -1.015648925512444 and parameters: {'feature_fraction': 0.5290418060840998, 'num_leaves': 223, 'bagging_fraction': 0.8005575058716043, 'min_sum_hessian_in_leaf': 0.679657809075816, 'reg_alpha': 1.5320059381854043e-08, 'reg_lambda': 5.360294728728285}. Best is trial 0 with value: -1.015648925512444.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 2 with hyperparameters {'feature_fraction': 0.5290418060840998, 'num_leaves': 223, 'bagging_fraction': 0.8005575058716043, 'min_sum_hessian_in_leaf': 0.679657809075816, 'reg_alpha': 1.5320059381854043e-08, 'reg_lambda': 5.360294728728285} scored -1.015648925512444 in 0:00:00.031916
# Optimization Progress:   1%|          | 1/101 [00:00<00:08, 12.45it/s, best_trial=0, best_value=-1.02]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.01565
# INFO:optuna.study.study:Trial 2 finished with value: -1.015648925512444 and parameters: {'feature_fraction': 0.9162213204002109, 'num_leaves': 66, 'bagging_fraction': 0.5909124836035503, 'min_sum_hessian_in_leaf': 0.00541524411940254, 'reg_alpha': 5.472429642032198e-06, 'reg_lambda': 0.00052821153945323}. Best is trial 0 with value: -1.015648925512444.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 3 with hyperparameters {'feature_fraction': 0.9162213204002109, 'num_leaves': 66, 'bagging_fraction': 0.5909124836035503, 'min_sum_hessian_in_leaf': 0.00541524411940254, 'reg_alpha': 5.472429642032198e-06, 'reg_lambda': 0.00052821153945323} scored -1.015648925512444 in 0:00:00.021646
# Optimization Progress:   3%|▎         | 3/101 [00:00<00:03, 25.76it/s, best_trial=0, best_value=-1.02]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.01565
# INFO:optuna.study.study:Trial 3 finished with value: -1.015648925512444 and parameters: {'feature_fraction': 0.7159725093210578, 'num_leaves': 85, 'bagging_fraction': 0.8059264473611898, 'min_sum_hessian_in_leaf': 0.003613894271216527, 'reg_alpha': 4.258943089524393e-06, 'reg_lambda': 1.9826980964985924e-05}. Best is trial 0 with value: -1.015648925512444.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 4 with hyperparameters {'feature_fraction': 0.7159725093210578, 'num_leaves': 85, 'bagging_fraction': 0.8059264473611898, 'min_sum_hessian_in_leaf': 0.003613894271216527, 'reg_alpha': 4.258943089524393e-06, 'reg_lambda': 1.9826980964985924e-05} scored -1.015648925512444 in 0:00:00.032756
# Optimization Progress:   3%|▎         | 3/101 [00:00<00:03, 25.76it/s, best_trial=0, best_value=-1.02]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.01565
# INFO:optuna.study.study:Trial 4 finished with value: -1.015648925512444 and parameters: {'feature_fraction': 0.728034992108518, 'num_leaves': 204, 'bagging_fraction': 0.5998368910791798, 'min_sum_hessian_in_leaf': 0.11400863701127326, 'reg_alpha': 0.0021465011216654484, 'reg_lambda': 2.6185068507773707e-08}. Best is trial 0 with value: -1.015648925512444.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 5 with hyperparameters {'feature_fraction': 0.728034992108518, 'num_leaves': 204, 'bagging_fraction': 0.5998368910791798, 'min_sum_hessian_in_leaf': 0.11400863701127326, 'reg_alpha': 0.0021465011216654484, 'reg_lambda': 2.6185068507773707e-08} scored -1.015648925512444 in 0:00:00.027967
# Optimization Progress:   4%|▍         | 4/101 [00:00<00:03, 25.76it/s, best_trial=0, best_value=-1.02]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.01565
# INFO:optuna.study.study:Trial 5 finished with value: -1.015648925512444 and parameters: {'feature_fraction': 0.8037724259507192, 'num_leaves': 56, 'bagging_fraction': 0.5325257964926398, 'min_sum_hessian_in_leaf': 6.245139574743075, 'reg_alpha': 4.905556676028774, 'reg_lambda': 0.18861495878553936}. Best is trial 0 with value: -1.015648925512444.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 6 with hyperparameters {'feature_fraction': 0.8037724259507192, 'num_leaves': 56, 'bagging_fraction': 0.5325257964926398, 'min_sum_hessian_in_leaf': 6.245139574743075, 'reg_alpha': 4.905556676028774, 'reg_lambda': 0.18861495878553936} scored -1.015648925512444 in 0:00:00.023413
# Optimization Progress:   6%|▌         | 6/101 [00:00<00:03, 24.72it/s, best_trial=0, best_value=-1.02]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.01565
# INFO:optuna.study.study:Trial 6 finished with value: -1.015648925512444 and parameters: {'feature_fraction': 0.6523068845866853, 'num_leaves': 39, 'bagging_fraction': 0.8421165132560784, 'min_sum_hessian_in_leaf': 0.057624872164786026, 'reg_alpha': 1.254134495897175e-07, 'reg_lambda': 0.00028614897264046574}. Best is trial 0 with value: -1.015648925512444.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 7 with hyperparameters {'feature_fraction': 0.6523068845866853, 'num_leaves': 39, 'bagging_fraction': 0.8421165132560784, 'min_sum_hessian_in_leaf': 0.057624872164786026, 'reg_alpha': 1.254134495897175e-07, 'reg_lambda': 0.00028614897264046574} scored -1.015648925512444 in 0:00:00.027754
# Optimization Progress:   6%|▌         | 6/101 [00:00<00:03, 24.72it/s, best_trial=0, best_value=-1.02]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.01565
# INFO:optuna.study.study:Trial 7 finished with value: -1.015648925512444 and parameters: {'feature_fraction': 0.5171942605576092, 'num_leaves': 234, 'bagging_fraction': 0.6293899908000085, 'min_sum_hessian_in_leaf': 0.4467752817973907, 'reg_alpha': 6.388511557344611e-06, 'reg_lambda': 0.0004793052550782129}. Best is trial 0 with value: -1.015648925512444.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial
finished with value: -1.015648925512444 and parameters: {'feature_fraction': 0.6535662699447691, 'num_leaves': 46, 'bagging_fraction': 0.5004764612910846, 'min_sum_hessian_in_leaf': 0.008114373802154184, 'reg_alpha': 5.970826690614986e-05, 'reg_lambda': 1.5548238863381538e-08}. Best is trial 0 with value: -1.015648925512444.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 34 with hyperparameters {'feature_fraction': 0.6535662699447691, 'num_leaves': 46, 'bagging_fraction': 0.5004764612910846, 'min_sum_hessian_in_leaf': 0.008114373802154184, 'reg_alpha': 5.970826690614986e-05, 'reg_lambda': 1.5548238863381538e-08} scored -1.015648925512444 in 0:00:00.055115
# Optimization Progress:  33%|███▎      | 33/101 [00:02<00:04, 14.07it/s, best_trial=0, best_value=-1.02]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.01565
# INFO:optuna.study.study:Trial 34 finished with value: -1.015648925512444 and parameters: {'feature_fraction': 0.7109837407464753, 'num_leaves': 83, 'bagging_fraction': 0.8288532787998742, 'min_sum_hessian_in_leaf': 0.0021030659167631566, 'reg_alpha': 0.000578401356129073, 'reg_lambda': 2.5109039344508354e-05}. Best is trial 0 with value: -1.015648925512444.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 35 with hyperparameters {'feature_fraction': 0.7109837407464753, 'num_leaves': 83, 'bagging_fraction': 0.8288532787998742, 'min_sum_hessian_in_leaf': 0.0021030659167631566, 'reg_alpha': 0.000578401356129073, 'reg_lambda': 2.5109039344508354e-05} scored -1.015648925512444 in 0:00:00.053139
# Optimization Progress:  35%|███▍      | 35/101 [00:02<00:04, 13.90it/s, best_trial=0, best_value=-1.02]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.01565
# INFO:optuna.study.study:Trial 35 finished with value: -1.015648925512444 and parameters: {'feature_fraction': 0.8255518928277965, 'num_leaves': 40, 'bagging_fraction': 0.6115907818516751, 'min_sum_hessian_in_leaf': 0.3438155317584177, 'reg_alpha': 0.014164852694921935, 'reg_lambda': 0.00012585717220483215}. Best is trial 0 with value: -1.015648925512444.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 36 with hyperparameters {'feature_fraction': 0.8255518928277965, 'num_leaves': 40, 'bagging_fraction': 0.6115907818516751, 'min_sum_hessian_in_leaf': 0.3438155317584177, 'reg_alpha': 0.014164852694921935, 'reg_lambda': 0.00012585717220483215} scored -1.015648925512444 in 0:00:00.061423
# ...
# INFO3:lightautoml.ml_algo.boost_cb:Shrink model to first 50 iterations.
# INFO:optuna.study.study:Trial 95 finished with value: -1.073638694104022 and parameters: {'max_depth': 3, 'l2_leaf_reg': 5.667469607993141, 'min_data_in_leaf': 9}. Best is trial 91 with value: -1.073601409358905.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 96 with hyperparameters {'max_depth': 3, 'l2_leaf_reg': 5.667469607993141, 'min_data_in_leaf': 9} scored -1.073638694104022 in 0:00:00.069118
# Optimization Progress:  95%|█████████▌| 96/101 [00:07<00:00, 10.01it/s, best_trial=91, best_value=-1.07]INFO3:lightautoml.ml_algo.boost_cb:0:	learn: 1.0877035	test: 1.0971897	best: 1.0971897 (0)	total: 901us	remaining: 2.7s
# INFO3:lightautoml.ml_algo.boost_cb:100:	learn: 0.8140587	test: 1.1663583	best: 1.0777744 (28)	total: 17.9ms	remaining: 513ms
# INFO3:lightautoml.ml_algo.boost_cb:Stopped by overfitting detector  (100 iterations wait)
# INFO3:lightautoml.ml_algo.boost_cb:bestTest = 1.077774354
# INFO3:lightautoml.ml_algo.boost_cb:bestIteration = 28
# INFO3:lightautoml.ml_algo.boost_cb:Shrink model to first 29 iterations.
# INFO:optuna.study.study:Trial 96 finished with value: -1.0777743437621623 and parameters: {'max_depth': 3, 'l2_leaf_reg': 0.8932074664729424, 'min_data_in_leaf': 9}. Best is trial 91 with value: -1.073601409358905.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 97 with hyperparameters {'max_depth': 3, 'l2_leaf_reg': 0.8932074664729424, 'min_data_in_leaf': 9} scored -1.0777743437621623 in 0:00:00.063638
# Optimization Progress:  95%|█████████▌| 96/101 [00:07<00:00, 10.01it/s, best_trial=91, best_value=-1.07]INFO3:lightautoml.ml_algo.boost_cb:0:	learn: 1.0948809	test: 1.0978807	best: 1.0978807 (0)	total: 606us	remaining: 1.82s
# INFO3:lightautoml.ml_algo.boost_cb:100:	learn: 0.9034810	test: 1.0898076	best: 1.0735989 (49)	total: 18.4ms	remaining: 529ms
# INFO3:lightautoml.ml_algo.boost_cb:Stopped by overfitting detector  (100 iterations wait)
# INFO3:lightautoml.ml_algo.boost_cb:bestTest = 1.07359885
# INFO3:lightautoml.ml_algo.boost_cb:bestIteration = 49
# INFO3:lightautoml.ml_algo.boost_cb:Shrink model to first 50 iterations.
# INFO:optuna.study.study:Trial 97 finished with value: -1.0735988453569583 and parameters: {'max_depth': 3, 'l2_leaf_reg': 6.145460828711426, 'min_data_in_leaf': 7}. Best is trial 97 with value: -1.0735988453569583.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 98 with hyperparameters {'max_depth': 3, 'l2_leaf_reg': 6.145460828711426, 'min_data_in_leaf': 7} scored -1.0735988453569583 in 0:00:00.069578
# Optimization Progress:  97%|█████████▋| 98/101 [00:07<00:00, 10.27it/s, best_trial=97, best_value=-1.07]INFO3:lightautoml.ml_algo.boost_cb:0:	learn: 1.0924742	test: 1.0975651	best: 1.0975651 (0)	total: 2.35ms	remaining: 7.04s
# INFO3:lightautoml.ml_algo.boost_cb:100:	learn: 0.8573767	test: 1.1147366	best: 1.0757953 (34)	total: 18.5ms	remaining: 530ms
# INFO3:lightautoml.ml_algo.boost_cb:Stopped by overfitting detector  (100 iterations wait)
# INFO3:lightautoml.ml_algo.boost_cb:bestTest = 1.075795326
# INFO3:lightautoml.ml_algo.boost_cb:bestIteration = 34
# INFO3:lightautoml.ml_algo.boost_cb:Shrink model to first 35 iterations.
# INFO:optuna.study.study:Trial 98 finished with value: -1.0757953135241394 and parameters: {'max_depth': 3, 'l2_leaf_reg': 2.976898097220441, 'min_data_in_leaf': 7}. Best is trial 97 with value: -1.0735988453569583.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 99 with hyperparameters {'max_depth': 3, 'l2_leaf_reg': 2.976898097220441, 'min_data_in_leaf': 7} scored -1.0757953135241394 in 0:00:00.065580
# Optimization Progress:  97%|█████████▋| 98/101 [00:08<00:00, 10.27it/s, best_trial=97, best_value=-1.07]INFO3:lightautoml.ml_algo.boost_cb:0:	learn: 1.0817904	test: 1.0970180	best: 1.0970180 (0)	total: 166us	remaining: 500ms
# INFO3:lightautoml.ml_algo.boost_cb:100:	learn: 0.7847894	test: 1.2503583	best: 1.0845546 (16)	total: 16.4ms	remaining: 470ms
# INFO3:lightautoml.ml_algo.boost_cb:Stopped by overfitting detector  (100 iterations wait)
# INFO3:lightautoml.ml_algo.boost_cb:bestTest = 1.084554608
# INFO3:lightautoml.ml_algo.boost_cb:bestIteration = 16
# INFO3:lightautoml.ml_algo.boost_cb:Shrink model to first 17 iterations.
# INFO:optuna.study.study:Trial 99 finished with value: -1.0845546178934713 and parameters: {'max_depth': 3, 'l2_leaf_reg': 2.780075858219524e-08, 'min_data_in_leaf': 6}. Best is trial 97 with value: -1.0735988453569583.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 100 with hyperparameters {'max_depth': 3, 'l2_leaf_reg': 2.780075858219524e-08, 'min_data_in_leaf': 6} scored -1.0845546178934713 in 0:00:00.061880
# Optimization Progress:  99%|█████████▉| 100/101 [00:08<00:00, 10.57it/s, best_trial=97, best_value=-1.07]INFO3:lightautoml.ml_algo.boost_cb:0:	learn: 1.0818389	test: 1.0970185	best: 1.0970185 (0)	total: 171us	remaining: 514ms
# INFO3:lightautoml.ml_algo.boost_cb:100:	learn: 0.7850440	test: 1.2488586	best: 1.0844857 (16)	total: 14.2ms	remaining: 407ms
# INFO3:lightautoml.ml_algo.boost_cb:Stopped by overfitting detector  (100 iterations wait)
# INFO3:lightautoml.ml_algo.boost_cb:bestTest = 1.084485706
# INFO3:lightautoml.ml_algo.boost_cb:bestIteration = 16
# INFO3:lightautoml.ml_algo.boost_cb:Shrink model to first 17 iterations.
# INFO:optuna.study.study:Trial 100 finished with value: -1.0844857086062092 and parameters: {'max_depth': 3, 'l2_leaf_reg': 0.004619790128848591, 'min_data_in_leaf': 6}. Best is trial 97 with value: -1.0735988453569583.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 101 with hyperparameters {'max_depth': 3, 'l2_leaf_reg': 0.004619790128848591, 'min_data_in_leaf': 6} scored -1.0844857086062092 in 0:00:00.064185
# Optimization Progress: 100%|██████████| 101/101 [00:08<00:00, 12.25it/s, best_trial=97, best_value=-1.07]
# [06:12:32] Hyperparameters optimization for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost completed
# INFO:lightautoml.ml_algo.tuning.optuna:Hyperparameters optimization for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost completed
# [06:12:32] The set of hyperparameters {'max_depth': 3, 'l2_leaf_reg': 6.145460828711426, 'min_data_in_leaf': 7}
#  achieve -1.0736 crossentropy
# INFO2:lightautoml.ml_algo.tuning.optuna:The set of hyperparameters {'max_depth': 3, 'l2_leaf_reg': 6.145460828711426, 'min_data_in_leaf': 7}
#  achieve -1.0736 crossentropy
# [06:12:32] Start fitting Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost ...
# INFO:lightautoml.ml_algo.base:Start fitting Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost ...
# DEBUG:lightautoml.ml_algo.base:Training params: {'task_type': 'CPU', 'thread_count': 2, 'random_seed': 42, 'num_trees': 3000, 'learning_rate': 0.03, 'l2_leaf_reg': 6.145460828711426, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 3, 'min_data_in_leaf': 7, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'boost_from_average': True, 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': 100, 'allow_writing_files': False, 'verbose_eval': 100}
# [06:12:32] ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost =====
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost =====
# INFO3:lightautoml.ml_algo.boost_cb:0:	learn: 1.0948809	test: 1.0978807	best: 1.0978807 (0)	total: 189us	remaining: 568ms
# INFO3:lightautoml.ml_algo.boost_cb:100:	learn: 0.9034810	test: 1.0898076	best: 1.0735989 (49)	total: 16.4ms	remaining: 472ms
# INFO3:lightautoml.ml_algo.boost_cb:Stopped by overfitting detector  (100 iterations wait)
# INFO3:lightautoml.ml_algo.boost_cb:bestTest = 1.07359885
# INFO3:lightautoml.ml_algo.boost_cb:bestIteration = 49
# INFO3:lightautoml.ml_algo.boost_cb:Shrink model to first 50 iterations.
# [06:12:32] ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost =====
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost =====
# INFO3:lightautoml.ml_algo.boost_cb:0:	learn: 1.0933268	test: 1.0978441	best: 1.0978441 (0)	total: 177us	remaining: 534ms
# INFO3:lightautoml.ml_algo.boost_cb:100:	learn: 0.8481200	test: 1.1109618	best: 1.0895469 (19)	total: 13.9ms	remaining: 399ms
# INFO3:lightautoml.ml_algo.boost_cb:Stopped by overfitting detector  (100 iterations wait)
# INFO3:lightautoml.ml_algo.boost_cb:bestTest = 1.089546854
# INFO3:lightautoml.ml_algo.boost_cb:bestIteration = 19
# INFO3:lightautoml.ml_algo.boost_cb:Shrink model to first 20 iterations.
# [06:12:32] Fitting Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost finished. score = -1.081572845864222
# INFO:lightautoml.ml_algo.base:Fitting Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost finished. score = -1.081572845864222
# [06:12:32] Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost fitting and predicting completed
# INFO:lightautoml.ml_algo.base:Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost fitting and predicting completed
# [06:12:32] Time left 71.65 secs
# INFO:lightautoml.automl.base:Time left 71.65 secs
# [06:12:32] Layer 1 training completed.
# INFO:lightautoml.automl.base:Layer 1 training completed.
# [06:12:32] Layer 2 train process start. Time left 71.64 secs
# INFO:lightautoml.automl.base:Layer 2 train process start. Time left 71.64 secs
# [06:12:32] Start fitting Lvl_1_Pipe_0_Mod_0_LinearL2 ...
# INFO:lightautoml.ml_algo.base:Start fitting Lvl_1_Pipe_0_Mod_0_LinearL2 ...
# DEBUG:lightautoml.ml_algo.base:Training params: {'tol': 1e-06, 'max_iter': 100, 'cs': [1e-05, 5e-05, 0.0001, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1, 5, 10, 50, 100, 500, 1000, 5000, 10000, 50000, 100000], 'early_stopping': 2, 'categorical_idx': [0, 1], 'embed_sizes': array([ 5, 11], dtype=int32), 'data_size': 29}
# [06:12:32] ===== Start working with fold 0 for Lvl_1_Pipe_0_Mod_0_LinearL2 =====
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 0 for Lvl_1_Pipe_0_Mod_0_LinearL2 =====
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1e-05 score = -1.0154040340596409
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5e-05 score = -1.0146448865326647
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0001 score = -1.0137169060818405
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0005 score = -1.0068993355211304
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.001 score = -1.0002588737802658
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.005 score = -0.9692267778188777
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.01 score = -0.9557420059277776
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.05 score = -0.9876113015036895
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.1 score = -1.0512203529774042
# [06:12:34] ===== Start working with fold 1 for Lvl_1_Pipe_0_Mod_0_LinearL2 =====
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 1 for Lvl_1_Pipe_0_Mod_0_LinearL2 =====
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1e-05 score = -1.0282129579538093
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5e-05 score = -1.0274564291042614
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0001 score = -1.0265281373481738
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0005 score = -1.019678285008996
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.001 score = -1.0131299218714318
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.005 score = -0.9852907468118794
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.01 score = -0.9793831422405775
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.05 score = -1.05283578894566
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.1 score = -1.138210104974916
# [06:12:35] Fitting Lvl_1_Pipe_0_Mod_0_LinearL2 finished. score = -0.9675625740841776
# INFO:lightautoml.ml_algo.base:Fitting Lvl_1_Pipe_0_Mod_0_LinearL2 finished. score = -0.9675625740841776
# [06:12:35] Lvl_1_Pipe_0_Mod_0_LinearL2 fitting and predicting completed
# INFO:lightautoml.ml_algo.base:Lvl_1_Pipe_0_Mod_0_LinearL2 fitting and predicting completed
# [06:12:35] Time left 68.29 secs
# INFO:lightautoml.automl.base:Time left 68.29 secs
# [06:12:35] Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
# INFO:lightautoml.ml_algo.base:Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
# DEBUG:lightautoml.ml_algo.base:Training params: {'task': 'train', 'learning_rate': 0.01, 'num_leaves': 16, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'bagging_freq': 1, 'max_depth': -1, 'verbosity': -1, 'reg_alpha': 1, 'reg_lambda': 0.0, 'min_split_gain': 0.0, 'zero_as_missing': False, 'num_threads': 2, 'max_bin': 255, 'min_data_in_bin': 3, 'num_trees': 3000, 'early_stopping_rounds': 200, 'random_state': 42, 'verbose_eval': 100}
# [06:12:35] ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.01565
# [06:12:35] ===== Start working with fold 1 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 1 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's multi_logloss: 1.0283
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's multi_logloss: 1.0283
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.0283
# [06:12:35] Fitting Lvl_1_Pipe_1_Mod_0_LightGBM finished. score = -1.021973776790689
# INFO:lightautoml.ml_algo.base:Fitting Lvl_1_Pipe_1_Mod_0_LightGBM finished. score = -1.021973776790689
# [06:12:35] Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# INFO:lightautoml.ml_algo.base:Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# [06:12:35] Time left 68.15 secs
# INFO:lightautoml.automl.base:Time left 68.15 secs
# [06:12:35] Layer 2 training completed.
# INFO:lightautoml.automl.base:Layer 2 training completed.
# [06:12:35] Blending: optimization starts with equal weights. Score = -0.9876691
# INFO:lightautoml.automl.blend:Blending: optimization starts with equal weights. Score = -0.9876691
# [06:12:35] Blending: iteration 0: score = -0.9675626, weights = [1. 0.]
# INFO:lightautoml.automl.blend:Blending: iteration 0: score = -0.9675626, weights = [1. 0.]
# [06:12:35] Blending: no improvements for score. Terminated.
# INFO:lightautoml.automl.blend:Blending: no improvements for score. Terminated.
# [06:12:35] Blending: best score = -0.9675626, best weights = [1. 0.]
# INFO:lightautoml.automl.blend:Blending: best score = -0.9675626, best weights = [1. 0.]
# [06:12:35] Automl preset training completed in 31.94 seconds
# INFO:lightautoml.automl.presets.base:Automl preset training completed in 31.94 seconds
# [06:12:35] Model description:
# Models on level 0:
# 	 2 averaged models Lvl_0_Pipe_0_Mod_0_LinearL2
# 	 2 averaged models Lvl_0_Pipe_1_Mod_0_LightGBM
# 	 2 averaged models Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM
# 	 2 averaged models Lvl_0_Pipe_1_Mod_2_CatBoost
# 	 2 averaged models Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost
#
# Final prediction for new objects (level 1) =
# 	 1.00000 * (2 averaged models Lvl_1_Pipe_0_Mod_0_LinearL2)
# INFO:lightautoml.automl.presets.base:Model description:
# Models on level 0:
# 	 2 averaged models Lvl_0_Pipe_0_Mod_0_LinearL2
# 	 2 averaged models Lvl_0_Pipe_1_Mod_0_LightGBM
# 	 2 averaged models Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM
# 	 2 averaged models Lvl_0_Pipe_1_Mod_2_CatBoost
# 	 2 averaged models Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost
#
# Final prediction for new objects (level 1) =
# 	 1.00000 * (2 averaged models Lvl_1_Pipe_0_Mod_0_LinearL2)

# %%
test_predictions = automl.predict(test_data).data
print(f'Prediction for test_data:\n{test_predictions}\nShape = {test_predictions.shape}')
#plt.plot(test_predictions.data[:],'.')
# Out:
# Prediction for test_data:
# [[0.46010476 0.1392829  0.40061238]
#  [0.21460739 0.19387731 0.5915153 ]
#  [0.25603968 0.18964243 0.55431795]
#  [0.4199378  0.15775493 0.42230734]
#  [0.42590743 0.14700247 0.42709017]
#  [0.3476116  0.16807124 0.48431718]
#  [0.4438575  0.1483731  0.40776944]
#  [0.45573616 0.14622036 0.39804348]
#  [0.42816865 0.14340046 0.42843094]
#  [0.4748853  0.13227466 0.39284003]
#  [0.39475715 0.17140031 0.4338426 ]
#  [0.43027118 0.14643538 0.42329347]
#  [0.38737142 0.15544656 0.45718205]]
# Shape = (13, 3)

# %%
RD = ReportDeco(output_path = 'tabularAutoML_model_report')

automl_rd = RD(
    TabularAutoML(
        task = task,
        timeout = TIMEOUT,
        cpu_limit = N_THREADS,
        reader_params = {'n_jobs': N_THREADS, 'cv': N_FOLDS, 'random_state': RANDOM_STATE}
    )
)

# %%
out_of_fold_predictions = automl_rd.fit_predict(train_data, roles = roles, verbose = 1)
# Out:
# [06:12:36] Stdout logging level is INFO.
# INFO:lightautoml.automl.presets.base:Stdout logging level is INFO.
# [06:12:36] Task: multiclass
# INFO:lightautoml.automl.presets.base:Task: multiclass
# [06:12:36] Start automl preset with listed constraints:
# INFO:lightautoml.automl.presets.base:Start automl preset with listed constraints:
# [06:12:36] - time: 100.00 seconds
# INFO:lightautoml.automl.presets.base:- time: 100.00 seconds
# [06:12:36] - CPU: 4 cores
# INFO:lightautoml.automl.presets.base:- CPU: 4 cores
# [06:12:36] - memory: 16 GB
# INFO:lightautoml.automl.presets.base:- memory: 16 GB
# [06:12:36] Train data shape: (48, 9)
# INFO:lightautoml.reader.base:Train data shape: (48, 9)
#
# INFO3:lightautoml.reader.base:Feats was rejected during automatic roles guess: []
# [06:12:36] Layer 1 train process start. Time left 99.89 secs
# INFO:lightautoml.automl.base:Layer 1 train process start. Time left 99.89 secs
# [06:12:36] Start fitting Lvl_0_Pipe_0_Mod_0_LinearL2 ...
# INFO:lightautoml.ml_algo.base:Start fitting Lvl_0_Pipe_0_Mod_0_LinearL2 ...
# DEBUG:lightautoml.ml_algo.base:Training params: {'tol': 1e-06, 'max_iter': 100, 'cs': [1e-05, 5e-05, 0.0001, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1, 5, 10, 50, 100, 500, 1000, 5000, 10000, 50000, 100000], 'early_stopping': 2, 'categorical_idx': [0, 1], 'embed_sizes': array([ 5, 11], dtype=int32), 'data_size': 14}
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1e-05 score = -1.015498572757575
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5e-05 score = -1.0153265354320486
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0001 score = -1.0151192710871708
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0005 score = -1.013630310996074
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.001 score = -1.0121681615679694
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.005 score = -1.011628931370353
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.01 score = -1.0217056782579255
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.05 score = -1.1449453210306642
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1e-05 score = -1.0283967375804315
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5e-05 score = -1.0282206723931733
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0001 score = -1.0280008921932884
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0005 score = -1.0263422080179934
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.001 score = -1.0245870246356261
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.005 score = -1.020449674130725
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.01 score = -1.0279762668848909
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.05 score = -1.1657022650126387
# [06:12:37] Fitting Lvl_0_Pipe_0_Mod_0_LinearL2 finished. score = -1.0160393027505388
# INFO:lightautoml.ml_algo.base:Fitting Lvl_0_Pipe_0_Mod_0_LinearL2 finished. score = -1.0160393027505388
# [06:12:37] Lvl_0_Pipe_0_Mod_0_LinearL2 fitting and predicting completed
# INFO:lightautoml.ml_algo.base:Lvl_0_Pipe_0_Mod_0_LinearL2 fitting and predicting completed
# [06:12:37] Time left 99.13 secs
# INFO:lightautoml.automl.base:Time left 99.13 secs
#
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.01565
# [06:12:37] Selector_LightGBM fitting and predicting completed
# INFO:lightautoml.ml_algo.base:Selector_LightGBM fitting and predicting completed
# [06:12:37] Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
# INFO:lightautoml.ml_algo.base:Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
# DEBUG:lightautoml.ml_algo.base:Training params: {'task': 'train', 'learning_rate': 0.01, 'num_leaves': 16, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'bagging_freq': 1, 'max_depth': -1, 'verbosity': -1, 'reg_alpha': 1, 'reg_lambda': 0.0, 'min_split_gain': 0.0, 'zero_as_missing': False, 'num_threads': 2, 'max_bin': 255, 'min_data_in_bin': 3, 'num_trees': 3000, 'early_stopping_rounds': 200, 'random_state': 42, 'verbose_eval': 100}
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.01565
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's multi_logloss: 1.0283
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's multi_logloss: 1.0283
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.0283
# [06:12:37] Fitting Lvl_0_Pipe_1_Mod_0_LightGBM finished. score = -1.021973776790689
# INFO:lightautoml.ml_algo.base:Fitting Lvl_0_Pipe_1_Mod_0_LightGBM finished. score = -1.021973776790689
# [06:12:37] Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# INFO:lightautoml.ml_algo.base:Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# [06:12:37] Start hyperparameters optimization for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM ... Time budget is 19.84 secs
# INFO:lightautoml.ml_algo.tuning.optuna:Start hyperparameters optimization for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM ... Time budget is 19.84 secs
# Optimization Progress:   0%|          | 0/101 [00:00<?, ?it/s]INFO:optuna.storages._in_memory:A new study created in memory with name: no-name-4008afa9-166e-469a-b432-4ae6aacdf3a0
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.01565
# INFO:optuna.study.study:Trial 0 finished with value: -1.015648925512444 and parameters: {'feature_fraction': 0.6872700594236812, 'num_leaves': 244, 'bagging_fraction': 0.8659969709057025, 'min_sum_hessian_in_leaf': 0.24810409748678125, 'reg_alpha': 2.5361081166471375e-07, 'reg_lambda': 2.5348407664333426e-07}. Best is trial 0 with value: -1.015648925512444.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 1 with hyperparameters {'feature_fraction': 0.6872700594236812, 'num_leaves': 244, 'bagging_fraction': 0.8659969709057025, 'min_sum_hessian_in_leaf': 0.24810409748678125, 'reg_alpha': 2.5361081166471375e-07, 'reg_lambda': 2.5348407664333426e-07} scored -1.015648925512444 in 0:00:00.022751
# Optimization Progress:   0%|          | 0/101 [00:00<?, ?it/s, best_trial=0, best_value=-1.02]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.01565
# INFO:optuna.study.study:Trial 1 finished with value: -1.015648925512444 and parameters: {'feature_fraction': 0.5290418060840998, 'num_leaves': 223, 'bagging_fraction': 0.8005575058716043, 'min_sum_hessian_in_leaf': 0.679657809075816, 'reg_alpha': 1.5320059381854043e-08, 'reg_lambda': 5.360294728728285}. Best is trial 0 with value: -1.015648925512444.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 2 with hyperparameters {'feature_fraction': 0.5290418060840998, 'num_leaves': 223, 'bagging_fraction': 0.8005575058716043, 'min_sum_hessian_in_leaf': 0.679657809075816, 'reg_alpha': 1.5320059381854043e-08, 'reg_lambda': 5.360294728728285} scored -1.015648925512444 in 0:00:00.029039
# Optimization Progress:   1%|          | 1/101 [00:00<00:08, 11.38it/s, best_trial=0, best_value=-1.02]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.01565
# INFO:optuna.study.study:Trial 2 finished with value: -1.015648925512444 and parameters: {'feature_fraction': 0.9162213204002109, 'num_leaves': 66, 'bagging_fraction': 0.5909124836035503, 'min_sum_hessian_in_leaf': 0.00541524411940254, 'reg_alpha': 5.472429642032198e-06, 'reg_lambda': 0.00052821153945323}. Best is trial 0 with value: -1.015648925512444.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 3 with hyperparameters {'feature_fraction': 0.9162213204002109, 'num_leaves': 66, 'bagging_fraction': 0.5909124836035503, 'min_sum_hessian_in_leaf': 0.00541524411940254, 'reg_alpha': 5.472429642032198e-06, 'reg_lambda': 0.00052821153945323} scored -1.015648925512444 in 0:00:00.032344
# Optimization Progress:   3%|▎         | 3/101 [00:00<00:04, 21.76it/s, best_trial=0, best_value=-1.02]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.01565
# INFO:optuna.study.study:Trial 3 finished with value: -1.015648925512444 and parameters: {'feature_fraction': 0.7159725093210578, 'num_leaves': 85, 'bagging_fraction': 0.8059264473611898, 'min_sum_hessian_in_leaf': 0.003613894271216527, 'reg_alpha': 4.258943089524393e-06, 'reg_lambda': 1.9826980964985924e-05}. Best is trial 0 with value: -1.015648925512444.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 4 with hyperparameters {'feature_fraction': 0.7159725093210578, 'num_leaves': 85, 'bagging_fraction': 0.8059264473611898, 'min_sum_hessian_in_leaf': 0.003613894271216527, 'reg_alpha': 4.258943089524393e-06, 'reg_lambda': 1.9826980964985924e-05} scored -1.015648925512444 in 0:00:00.029827
# Optimization Progress:   3%|▎         | 3/101 [00:00<00:04, 21.76it/s, best_trial=0, best_value=-1.02]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.01565
# INFO:optuna.study.study:Trial 4 finished with value: -1.015648925512444 and parameters: {'feature_fraction': 0.728034992108518, 'num_leaves': 204, 'bagging_fraction': 0.5998368910791798, 'min_sum_hessian_in_leaf': 0.11400863701127326, 'reg_alpha': 0.0021465011216654484, 'reg_lambda': 2.6185068507773707e-08}. Best is trial 0 with value: -1.015648925512444.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 5 with hyperparameters {'feature_fraction': 0.728034992108518, 'num_leaves': 204, 'bagging_fraction': 0.5998368910791798, 'min_sum_hessian_in_leaf': 0.11400863701127326, 'reg_alpha': 0.0021465011216654484, 'reg_lambda': 2.6185068507773707e-08} scored -1.015648925512444 in 0:00:00.028758
# Optimization Progress:   4%|▍         | 4/101 [00:00<00:04, 21.76it/s, best_trial=0, best_value=-1.02]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.01565
# INFO:optuna.study.study:Trial 5 finished with value: -1.015648925512444 and parameters: {'feature_fraction': 0.8037724259507192, 'num_leaves': 56, 'bagging_fraction': 0.5325257964926398, 'min_sum_hessian_in_leaf': 6.245139574743075, 'reg_alpha': 4.905556676028774, 'reg_lambda': 0.18861495878553936}. Best is trial 0 with value: -1.015648925512444.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 6 with hyperparameters {'feature_fraction': 0.8037724259507192, 'num_leaves': 56, 'bagging_fraction': 0.5325257964926398, 'min_sum_hessian_in_leaf': 6.245139574743075, 'reg_alpha': 4.905556676028774, 'reg_lambda': 0.18861495878553936} scored -1.015648925512444 in 0:00:00.022746
# Optimization Progress:   6%|▌         | 6/101 [00:00<00:04, 22.86it/s, best_trial=0, best_value=-1.02]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.01565
# INFO:optuna.study.study:Trial 6 finished with value: -1.015648925512444 and parameters: {'feature_fraction': 0.6523068845866853, 'num_leaves': 39, 'bagging_fraction': 0.8421165132560784, 'min_sum_hessian_in_leaf': 0.057624872164786026, 'reg_alpha': 1.254134495897175e-07, 'reg_lambda': 0.00028614897264046574}. Best is trial 0 with value: -1.015648925512444.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 7 with hyperparameters {'feature_fraction': 0.6523068845866853, 'num_leaves': 39, 'bagging_fraction': 0.8421165132560784, 'min_sum_hessian_in_leaf': 0.057624872164786026, 'reg_alpha': 1.254134495897175e-07, 'reg_lambda': 0.00028614897264046574} scored -1.015648925512444 in 0:00:00.024928
# Optimization Progress:   6%|▌         | 6/101 [00:00<00:04, 22.86it/s, best_trial=0, best_value=-1.02]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.01565
# INFO:optuna.study.study:Trial 7 finished with value: -1.015648925512444 and parameters: {'feature_fraction': 0.5171942605576092, 'num_leaves': 234, 'bagging_fraction': 0.6293899908000085, 'min_sum_hessian_in_leaf': 0.4467752817973907, 'reg_alpha': 6.388511557344611e-06, 'reg_lambda': 0.0004793052550782129}. Best is trial 0 with value: -1.015648925512444.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 8 with hyperparameters {'feature_fraction': 0.5171942605576092, 'num_leaves': 234, 'bagging_fraction': 0.6293899908000085, 'min_sum_hessian_in_leaf': 0.4467752817973907, 'reg_alpha': 6.388511557344611e-06, 'reg_lambda': 0.0004793052550782129} scored -1.015648925512444 in 0:00:00.035022
# Optimization Progress:   7%|▋         | 7/101 [00:00<00:04, 22.86it/s, best_trial=0, best_value=-1.02]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.01565
# INFO:optuna.study.study:Trial 8 finished with value: -1.015648925512444 and parameters: {'feature_fraction': 0.7733551396716398, 'num_leaves': 60, 'bagging_fraction': 0.9847923138822793, 'min_sum_hessian_in_leaf': 1.2604664585649468, 'reg_alpha': 2.854239907497756, 'reg_lambda': 1.1309571585271483}. Best is trial 0 with value: -1.015648925512444.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 9 with hyperparameters {'feature_fraction': 0.7733551396716398, 'num_leaves': 60, 'bagging_fraction': 0.9847923138822793, 'min_sum_hessian_in_leaf': 1.2604664585649468, 'reg_alpha': 2.854239907497756, 'reg_lambda': 1.1309571585271483} scored -1.015648925512444 in 0:00:00.022004
# Optimization Progress:   9%|▉         | 9/101 [00:00<00:04, 22.65it/s, best_trial=0, best_value=-1.02]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.01565
# INFO:optuna.study.study:Trial 9 finished with value: -1.015648925512444 and parameters: {'feature_fraction': 0.7989499894055425, 'num_leaves': 237, 'bagging_fraction': 0.5442462510259598, 'min_sum_hessian_in_leaf': 0.006080390190296602, 'reg_alpha': 2.5529693461039728e-08, 'reg_lambda': 8.471746987003668e-06}. Best is trial 0 with value: -1.015648925512444.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 10 with hyperparameters {'feature_fraction': 0.7989499894055425, 'num_leaves': 237, 'bagging_fraction': 0.5442462510259598, 'min_sum_hessian_in_leaf': 0.006080390190296602, 'reg_alpha': 2.5529693461039728e-08, 'reg_lambda': 8.471746987003668e-06} scored -1.015648925512444 in 0:00:00.030369
# Optimization Progress:   9%|▉         | 9/101 [00:00<00:04, 22.65it/s, best_trial=0, best_value=-1.02]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.01565
# INFO:optuna.study.study:Trial

# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 36 with hyperparameters {'feature_fraction': 0.8255518928277965, 'num_leaves': 40, 'bagging_fraction': 0.6115907818516751, 'min_sum_hessian_in_leaf': 0.3438155317584177, 'reg_alpha': 0.014164852694921935, 'reg_lambda': 0.00012585717220483215} scored -1.015648925512444 in 0:00:00.059690
# Optimization Progress:  35%|███▍      | 35/101 [00:02<00:04, 14.30it/s, best_trial=0, best_value=-1.02]INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's multi_logloss: 1.01565
# ...
# Optimization Progress:  93%|█████████▎| 94/101 [00:07<00:00, 10.46it/s, best_trial=91, best_value=-1.07]INFO3:lightautoml.ml_algo.boost_cb:0:	learn: 1.0946481	test: 1.0978455	best: 1.0978455 (0)	total: 169us	remaining: 508ms
# INFO3:lightautoml.ml_algo.boost_cb:100:	learn: 0.8973560	test: 1.0920886	best: 1.0736387 (49)	total: 17ms	remaining: 488ms
# INFO3:lightautoml.ml_algo.boost_cb:Stopped by overfitting detector  (100 iterations wait)
# INFO3:lightautoml.ml_algo.boost_cb:bestTest = 1.073638704
# INFO3:lightautoml.ml_algo.boost_cb:bestIteration = 49
# INFO3:lightautoml.ml_algo.boost_cb:Shrink model to first 50 iterations.
# INFO:optuna.study.study:Trial 95 finished with value: -1.073638694104022 and parameters: {'max_depth': 3, 'l2_leaf_reg': 5.667469607993141, 'min_data_in_leaf': 9}. Best is trial 91 with value: -1.073601409358905.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 96 with hyperparameters {'max_depth': 3, 'l2_leaf_reg': 5.667469607993141, 'min_data_in_leaf': 9} scored -1.073638694104022 in 0:00:00.070192
# Optimization Progress:  95%|█████████▌| 96/101 [00:07<00:00, 10.39it/s, best_trial=91, best_value=-1.07]INFO3:lightautoml.ml_algo.boost_cb:0:	learn: 1.0877035	test: 1.0971897	best: 1.0971897 (0)	total: 397us	remaining: 1.19s
# INFO3:lightautoml.ml_algo.boost_cb:100:	learn: 0.8140587	test: 1.1663583	best: 1.0777744 (28)	total: 17.8ms	remaining: 511ms
# INFO3:lightautoml.ml_algo.boost_cb:Stopped by overfitting detector  (100 iterations wait)
# INFO3:lightautoml.ml_algo.boost_cb:bestTest = 1.077774354
# INFO3:lightautoml.ml_algo.boost_cb:bestIteration = 28
# INFO3:lightautoml.ml_algo.boost_cb:Shrink model to first 29 iterations.
# INFO:optuna.study.study:Trial 96 finished with value: -1.0777743437621623 and parameters: {'max_depth': 3, 'l2_leaf_reg': 0.8932074664729424, 'min_data_in_leaf': 9}. Best is trial 91 with value: -1.073601409358905.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 97 with hyperparameters {'max_depth': 3, 'l2_leaf_reg': 0.8932074664729424, 'min_data_in_leaf': 9} scored -1.0777743437621623 in 0:00:00.069923
# Optimization Progress:  95%|█████████▌| 96/101 [00:07<00:00, 10.39it/s, best_trial=91, best_value=-1.07]INFO3:lightautoml.ml_algo.boost_cb:0:	learn: 1.0948809	test: 1.0978807	best: 1.0978807 (0)	total: 174us	remaining: 523ms
# INFO3:lightautoml.ml_algo.boost_cb:100:	learn: 0.9034810	test: 1.0898076	best: 1.0735989 (49)	total: 15.6ms	remaining: 447ms
# INFO3:lightautoml.ml_algo.boost_cb:Stopped by overfitting detector  (100 iterations wait)
# INFO3:lightautoml.ml_algo.boost_cb:bestTest = 1.07359885
# INFO3:lightautoml.ml_algo.boost_cb:bestIteration = 49
# INFO3:lightautoml.ml_algo.boost_cb:Shrink model to first 50 iterations.
# INFO:optuna.study.study:Trial 97 finished with value: -1.0735988453569583 and parameters: {'max_depth': 3, 'l2_leaf_reg': 6.145460828711426, 'min_data_in_leaf': 7}. Best is trial 97 with value: -1.0735988453569583.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 98 with hyperparameters {'max_depth': 3, 'l2_leaf_reg': 6.145460828711426, 'min_data_in_leaf': 7} scored -1.0735988453569583 in 0:00:00.071238
# Optimization Progress:  97%|█████████▋| 98/101 [00:07<00:00, 10.34it/s, best_trial=97, best_value=-1.07]INFO3:lightautoml.ml_algo.boost_cb:0:	learn: 1.0924742	test: 1.0975651	best: 1.0975651 (0)	total: 190us	remaining: 570ms
# INFO3:lightautoml.ml_algo.boost_cb:100:	learn: 0.8573767	test: 1.1147366	best: 1.0757953 (34)	total: 17.7ms	remaining: 507ms
# INFO3:lightautoml.ml_algo.boost_cb:Stopped by overfitting detector  (100 iterations wait)
# INFO3:lightautoml.ml_algo.boost_cb:bestTest = 1.075795326
# INFO3:lightautoml.ml_algo.boost_cb:bestIteration = 34
# INFO3:lightautoml.ml_algo.boost_cb:Shrink model to first 35 iterations.
# INFO:optuna.study.study:Trial 98 finished with value: -1.0757953135241394 and parameters: {'max_depth': 3, 'l2_leaf_reg': 2.976898097220441, 'min_data_in_leaf': 7}. Best is trial 97 with value: -1.0735988453569583.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 99 with hyperparameters {'max_depth': 3, 'l2_leaf_reg': 2.976898097220441, 'min_data_in_leaf': 7} scored -1.0757953135241394 in 0:00:00.068808
# Optimization Progress:  97%|█████████▋| 98/101 [00:07<00:00, 10.34it/s, best_trial=97, best_value=-1.07]INFO3:lightautoml.ml_algo.boost_cb:0:	learn: 1.0817904	test: 1.0970180	best: 1.0970180 (0)	total: 1.37ms	remaining: 4.11s
# INFO3:lightautoml.ml_algo.boost_cb:100:	learn: 0.7847894	test: 1.2503583	best: 1.0845546 (16)	total: 19.9ms	remaining: 572ms
# INFO3:lightautoml.ml_algo.boost_cb:Stopped by overfitting detector  (100 iterations wait)
# INFO3:lightautoml.ml_algo.boost_cb:bestTest = 1.084554608
# INFO3:lightautoml.ml_algo.boost_cb:bestIteration = 16
# INFO3:lightautoml.ml_algo.boost_cb:Shrink model to first 17 iterations.
# INFO:optuna.study.study:Trial 99 finished with value: -1.0845546178934713 and parameters: {'max_depth': 3, 'l2_leaf_reg': 2.780075858219524e-08, 'min_data_in_leaf': 6}. Best is trial 97 with value: -1.0735988453569583.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 100 with hyperparameters {'max_depth': 3, 'l2_leaf_reg': 2.780075858219524e-08, 'min_data_in_leaf': 6} scored -1.0845546178934713 in 0:00:00.067228
# Optimization Progress:  99%|█████████▉| 100/101 [00:07<00:00, 10.39it/s, best_trial=97, best_value=-1.07]INFO3:lightautoml.ml_algo.boost_cb:0:	learn: 1.0818389	test: 1.0970185	best: 1.0970185 (0)	total: 177us	remaining: 533ms
# INFO3:lightautoml.ml_algo.boost_cb:100:	learn: 0.7850440	test: 1.2488586	best: 1.0844857 (16)	total: 21.5ms	remaining: 616ms
# INFO3:lightautoml.ml_algo.boost_cb:Stopped by overfitting detector  (100 iterations wait)
# INFO3:lightautoml.ml_algo.boost_cb:bestTest = 1.084485706
# INFO3:lightautoml.ml_algo.boost_cb:bestIteration = 16
# INFO3:lightautoml.ml_algo.boost_cb:Shrink model to first 17 iterations.
# INFO:optuna.study.study:Trial 100 finished with value: -1.0844857086062092 and parameters: {'max_depth': 3, 'l2_leaf_reg': 0.004619790128848591, 'min_data_in_leaf': 6}. Best is trial 97 with value: -1.0735988453569583.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 101 with hyperparameters {'max_depth': 3, 'l2_leaf_reg': 0.004619790128848591, 'min_data_in_leaf': 6} scored -1.0844857086062092 in 0:00:00.080227
# Optimization Progress: 100%|██████████| 101/101 [00:07<00:00, 12.97it/s, best_trial=97, best_value=-1.07]
# [06:12:54] Hyperparameters optimization for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost completed
# INFO:lightautoml.ml_algo.tuning.optuna:Hyperparameters optimization for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost completed
# INFO2:lightautoml.ml_algo.tuning.optuna:The set of hyperparameters {'max_depth': 3, 'l2_leaf_reg': 6.145460828711426, 'min_data_in_leaf': 7}
#  achieve -1.0736 crossentropy
# [06:12:54] Start fitting Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost ...
# INFO:lightautoml.ml_algo.base:Start fitting Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost ...
# DEBUG:lightautoml.ml_algo.base:Training params: {'task_type': 'CPU', 'thread_count': 2, 'random_seed': 42, 'num_trees': 3000, 'learning_rate': 0.03, 'l2_leaf_reg': 6.145460828711426, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 3, 'min_data_in_leaf': 7, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'boost_from_average': True, 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': 100, 'allow_writing_files': False, 'verbose_eval': 100}
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost =====
# INFO3:lightautoml.ml_algo.boost_cb:0:	learn: 1.0948809	test: 1.0978807	best: 1.0978807 (0)	total: 1.32ms	remaining: 3.97s
# INFO3:lightautoml.ml_algo.boost_cb:100:	learn: 0.9034810	test: 1.0898076	best: 1.0735989 (49)	total: 13.5ms	remaining: 389ms
# INFO3:lightautoml.ml_algo.boost_cb:Stopped by overfitting detector  (100 iterations wait)
# INFO3:lightautoml.ml_algo.boost_cb:bestTest = 1.07359885
# INFO3:lightautoml.ml_algo.boost_cb:bestIteration = 49
# INFO3:lightautoml.ml_algo.boost_cb:Shrink model to first 50 iterations.
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost =====
# INFO3:lightautoml.ml_algo.boost_cb:0:	learn: 1.0933268	test: 1.0978441	best: 1.0978441 (0)	total: 168us	remaining: 506ms
# INFO3:lightautoml.ml_algo.boost_cb:100:	learn: 0.8481200	test: 1.1109618	best: 1.0895469 (19)	total: 13.6ms	remaining: 391ms
# INFO3:lightautoml.ml_algo.boost_cb:Stopped by overfitting detector  (100 iterations wait)
# INFO3:lightautoml.ml_algo.boost_cb:bestTest = 1.089546854
# INFO3:lightautoml.ml_algo.boost_cb:bestIteration = 19
# INFO3:lightautoml.ml_algo.boost_cb:Shrink model to first 20 iterations.
# [06:12:55] Fitting Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost finished. score = -1.081572845864222
# INFO:lightautoml.ml_algo.base:Fitting Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost finished. score = -1.081572845864222
# [06:12:55] Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost fitting and predicting completed
# INFO:lightautoml.ml_algo.base:Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost fitting and predicting completed
# [06:12:55] Time left 81.15 secs
# INFO:lightautoml.automl.base:Time left 81.15 secs
# [06:12:55] Layer 1 training completed.
# INFO:lightautoml.automl.base:Layer 1 training completed.
# [06:12:55] Layer 2 train process start. Time left 81.13 secs
# INFO:lightautoml.automl.base:Layer 2 train process start. Time left 81.13 secs
# [06:12:55] Start fitting Lvl_1_Pipe_0_Mod_0_LinearL2 ...
# INFO:lightautoml.ml_algo.base:Start fitting Lvl_1_Pipe_0_Mod_0_LinearL2 ...
# DEBUG:lightautoml.ml_algo.base:Training params: {'tol': 1e-06, 'max_iter': 100, 'cs': [1e-05, 5e-05, 0.0001, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1, 5, 10, 50, 100, 500, 1000, 5000, 10000, 50000, 100000], 'early_stopping': 2, 'categorical_idx': [0, 1], 'embed_sizes': array([ 5, 11], dtype=int32), 'data_size': 29}
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 0 for Lvl_1_Pipe_0_Mod_0_LinearL2 =====
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1e-05 score = -1.0154040340596409
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5e-05 score = -1.0146448865326647
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0001 score = -1.0137169060818405
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0005 score = -1.0068993355211304
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.001 score = -1.0002588737802658
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.005 score = -0.9692267778188777
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.01 score = -0.9557420059277776
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.05 score = -0.9876113015036895
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.1 score = -1.0512203529774042
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 1 for Lvl_1_Pipe_0_Mod_0_LinearL2 =====
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1e-05 score = -1.0282129579538093
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5e-05 score = -1.0274564291042614
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0001 score = -1.0265281373481738
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0005 score = -1.019678285008996
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.001 score = -1.0131299218714318
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.005 score = -0.9852907468118794
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.01 score = -0.9793831422405775
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.05 score = -1.05283578894566
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.1 score = -1.138210104974916
# [06:12:58] Fitting Lvl_1_Pipe_0_Mod_0_LinearL2 finished. score = -0.9675625740841776
# INFO:lightautoml.ml_algo.base:Fitting Lvl_1_Pipe_0_Mod_0_LinearL2 finished. score = -0.9675625740841776
# [06:12:58] Lvl_1_Pipe_0_Mod_0_LinearL2 fitting and predicting completed
# INFO:lightautoml.ml_algo.base:Lvl_1_Pipe_0_Mod_0_LinearL2 fitting and predicting completed
# [06:12:58] Time left 78.11 secs
# INFO:lightautoml.automl.base:Time left 78.11 secs
# [06:12:58] Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
# INFO:lightautoml.ml_algo.base:Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
# DEBUG:lightautoml.ml_algo.base:Training params: {'task': 'train', 'learning_rate': 0.01, 'num_leaves': 16, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'bagging_freq': 1, 'max_depth': -1, 'verbosity': -1, 'reg_alpha': 1, 'reg_lambda': 0.0, 'min_split_gain': 0.0, 'zero_as_missing': False, 'num_threads': 2, 'max_bin': 255, 'min_data_in_bin': 3, 'num_trees': 3000, 'early_stopping_rounds': 200, 'random_state': 42, 'verbose_eval': 100}
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's multi_logloss: 1.01565
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.01565
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 1 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# INFO3:lightautoml.ml_algo.boost_lgbm:[100]	valid's multi_logloss: 1.0283
# INFO3:lightautoml.ml_algo.boost_lgbm:[200]	valid's multi_logloss: 1.0283
# INFO3:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [1]	valid's multi_logloss: 1.0283
# [06:12:58] Fitting Lvl_1_Pipe_1_Mod_0_LightGBM finished. score = -1.021973776790689
# INFO:lightautoml.ml_algo.base:Fitting Lvl_1_Pipe_1_Mod_0_LightGBM finished. score = -1.021973776790689
# [06:12:58] Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# INFO:lightautoml.ml_algo.base:Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# [06:12:58] Time left 77.95 secs
# INFO:lightautoml.automl.base:Time left 77.95 secs
# [06:12:58] Layer 2 training completed.
# INFO:lightautoml.automl.base:Layer 2 training completed.
# [06:12:58] Blending: optimization starts with equal weights. Score = -0.9876691
# INFO:lightautoml.automl.blend:Blending: optimization starts with equal weights. Score = -0.9876691
# [06:12:58] Blending: iteration 0: score = -0.9675626, weights = [1. 0.]
# INFO:lightautoml.automl.blend:Blending: iteration 0: score = -0.9675626, weights = [1. 0.]
# [06:12:58] Blending: no improvements for score. Terminated.
# INFO:lightautoml.automl.blend:Blending: no improvements for score. Terminated.
# [06:12:58] Blending: best score = -0.9675626, best weights = [1. 0.]
# INFO:lightautoml.automl.blend:Blending: best score = -0.9675626, best weights = [1. 0.]
# [06:12:58] Automl preset training completed in 22.13 seconds
# INFO:lightautoml.automl.presets.base:Automl preset training completed in 22.13 seconds
# [06:12:58] Model description:
# Models on level 0:
# 	 2 averaged models Lvl_0_Pipe_0_Mod_0_LinearL2
# 	 2 averaged models Lvl_0_Pipe_1_Mod_0_LightGBM
# 	 2 averaged models Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM
# 	 2 averaged models Lvl_0_Pipe_1_Mod_2_CatBoost
# 	 2 averaged models Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost
#
# Final prediction for new objects (level 1) =
# 	 1.00000 * (2 averaged models Lvl_1_Pipe_0_Mod_0_LinearL2)
# INFO:lightautoml.automl.presets.base:Model description:
# Models on level 0:
# 	 2 averaged models Lvl_0_Pipe_0_Mod_0_LinearL2
# 	 2 averaged models Lvl_0_Pipe_1_Mod_0_LightGBM
# 	 2 averaged models Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM
# 	 2 averaged models Lvl_0_Pipe_1_Mod_2_CatBoost
# 	 2 averaged models Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost
#
# Final prediction for new objects (level 1) =
# 	 1.00000 * (2 averaged models Lvl_1_Pipe_0_Mod_0_LinearL2)

# %%
# Fast feature importances calculation
# we will use automl_rd.model instead automl_rd because
# we want to take the importances from the model, not from the report.

fast_fi = automl_rd.model.get_feature_scores('fast')
#fast_fi = automl.model.get_feature_scores('fast')
fast_fi.set_index('Feature')['Importance'].plot.bar(figsize = (13, 3), grid = True)
# Out:
# <Axes: xlabel='Feature'>

# %%
explainer = SSWARM(automl_rd.model)
shap_values = explainer.shap_values(test_data, n_jobs=N_THREADS)
# Out:
# 100%|██████████| 1500/1500 [00:41<00:00, 35.97it/s]

# %%
shap.summary_plot(shap_values[0], test_data[list(explainer.used_feats)])

# %%
shap.summary_plot(shap_values[1], test_data[list(explainer.used_feats)])

# %%
shap.summary_plot(shap_values[2], test_data[list(explainer.used_feats)])

# %%
# individual force plot
shap.force_plot(explainer.expected_value[0], shap_values[0][0],
                test_data[explainer.used_feats].iloc[0], matplotlib=True)

# %%
# individual force plot
shap.force_plot(explainer.expected_value[1], shap_values[1][0],
                test_data[explainer.used_feats].iloc[1], matplotlib=True)

# %%
X_test = test_data
X_test.reset_index(drop=['index'], inplace=True)
X_test = X_test.drop(columns=TARGET_NAME)
X_test.reset_index(drop=['index'], inplace=True)

# %%
shap.initjs()
shap.force_plot(explainer.expected_value[2],
                shap_values[2], X_test)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},l=Symbol.for("react.portal"),u=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:l,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=u.T,n=o.p;try{if(u.T=null,o.p=2,e)return e()}finally{u.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return u.H.useFormState(e,t,n)},t.useFormStatus=function(){return u.H.useHostTransitionStatus()},t.version="19.2.0"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function l(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}function u(e){var t=e,n=e;if(e.alternate)for(;t.return;)t=t.return;else{e=t;do{!!(4098&(t=e).flags)&&(n=t.return),e=t.return}while(e)}return 3===t.tag?n:null}function s(e){if(13===e.tag){var t=e.memoizedState;if(null===t&&n ...
# <div id='i3A8SUTDT6J8KGKYQ91E4'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.4478124976158142, "link": "identity", "featureNames": ["Avg_Resp_Left_Mean", "Avg_Resp_Left_Std", "Avg_Resp_Left_Hurst", "Avg_Resp_Right_Mean", "Avg_Resp_Right_Std", "Avg_Resp_Right_Hurst", "Avg_Resp_DTW_Cluster", "Inh_Thresh_DTW_Cluster"], "explanations": [{"outValue": 0.40061238408088684, "simIndex": 10.0, "features": {"0": {"effect": -0.0008553439016187507, "value": 149.7611607166667}, "1": {"effect": -0.00016348841600276098, "value": 53.17608108753196}, "2": {"effect": 0.011292965313710325, "value": 2.0364850415963325}, "3": {"effect": -0.01503428424421879, "value": 121.67276785833332}, "4": {"effect": -0.025562771045535136, "value": 21.297929227473507}, "5": {"effect": -0.0058521491194